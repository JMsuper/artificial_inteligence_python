# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.formula.api import ols

POPULATION_SIZE = 16	# 개체 집단의 크기
MUTATION_RATE = 0.2	# 돌연 변이 확률
SIZE = 9			# 하나의 염색체에서 유전자 개수		
df = pd.read_excel('distance.xlsx',header=1,usecols=range(1,10))
dist_table = df.values.tolist()
TARGET_VAL = 1018

# 최단 경로 : (0, 1, 2, 8, 7, 6, 5, 4, 3)
# 최단 거리 : 1018

# 염색체를 클래스로 정의한다. 
class Chromosome:
    def __init__(self, g = []):
        self.genes = g		# 유전자는 리스트로 구현된다. 
        self.fitness = 0		# 적합도
        if self.genes.__len__()==0:	# 염색체가 초기 상태이면 초기화한다. 
            temp_list = list(range(9))
            random.shuffle(temp_list)
            self.genes = temp_list.copy()
        
    def cal_fitness(self):		# 적합도를 계산한다. 
        global dist_table
        self.fitness = 0
        value = 0

        prev_node = self.genes[0]
        for i in range(1,9):
            node = self.genes[i]
            value += int(dist_table[prev_node][node])
            prev_node = node
        value += int(dist_table[self.genes[8]][self.genes[0]])

        self.fitness = TARGET_VAL * 2 - value if TARGET_VAL * 2 - value > 0 else 1
        return self.fitness

    def __str__(self):
        return self.genes.__str__()

# 염색체와 적합도를 출력한다. 
def print_p(pop):
    i = 0
    for x in pop:
        print("염색체 #", i, "=", x, "적합도=", x.fitness)
        i += 1
    print("")

# 선택 연산
def select(pop):
    max_value  = sum([c.cal_fitness() for c in population])
    pick    = random.uniform(0, max_value)
    current = 0
    
    # 룰렛휠에서 어떤 조각에 속하는지를 알아내는 루프
    for c in pop:
        current += c.cal_fitness()
        if current > pick:
            return c

# 교차 연산
def crossover(pop):
    father = select(pop)
    mother = select(pop)
    length = random.randint(1, SIZE - 1)
    idx = random.randint(0, SIZE - length)

    t_child1 = mother.genes[idx:idx + length].copy()
    t_child2 = father.genes[idx:idx + length].copy()

    child1 = list(filter(lambda x: not x in t_child1,father.genes))
    child2 = list(filter(lambda x: not x in t_child2,mother.genes))

    child1 = child1[:idx] + t_child1 + child1[idx:]
    child2 = child2[:idx] + t_child2 + child2[idx:]

    return (child1, child2)
    
# 돌연변이 연산
def mutate(c):
    if random.random() < MUTATION_RATE:
        x, y = random.sample(list(range(0,9)),2)
        c.genes[y], c.genes[x] = c.genes[x], c.genes[y]

# 메인 프로그램
population = []
i=0
fitness_list = []

# 초기 염색체를 생성하여 객체 집단에 추가한다. 
while i<POPULATION_SIZE:
    population.append(Chromosome())
    i += 1

count=0
population.sort(key=lambda x: x.cal_fitness(),reverse=True)
print("세대 번호=", count)
print_p(population)
count=1

max_fitness = 0

while population[0].fitness < TARGET_VAL:
    if population[0].fitness > max_fitness:
        MUTATION_RATE = MUTATION_RATE * 0.9
        max_fitness = population[0].fitness
    new_pop = []

    # 선택과 교차 연산
    for _ in range(POPULATION_SIZE//2):
        c1, c2 = crossover(population)
        new_pop.append(Chromosome(c1))
        new_pop.append(Chromosome(c2))

    # 자식 세대가 부모 세대를 대체한다. 
    # 깊은 복사를 수행한다. 
    population = new_pop.copy()
    
    # 돌연변이 연산
    for c in population: mutate(c)

    # 출력을 위한 정렬
    population.sort(key=lambda x: x.cal_fitness(),reverse=True)
    fitness_list.append(population[0].fitness)
    print("세대 번호=", count)
    print_p(population)
    count += 1
    if count > 50000 : break

x, y = range(len(fitness_list)),fitness_list
fit_line = np.polyfit(x,y,1)
x_minmax = np.array([min(x), max(x)])
fit_y = x_minmax * fit_line[0] + fit_line[1]

plt.plot(fitness_list,label='fitness')
plt.plot(x_minmax, fit_y, color = 'red',label='regression')
plt.xlabel('generation number')
plt.ylabel('fitness')
plt.legend()
plt.show()
# Out:
# 세대 번호= 0
# 염색체 # 0 = [6, 7, 5, 2, 8, 0, 3, 1, 4] 적합도= 751
# 염색체 # 1 = [1, 8, 7, 6, 2, 5, 3, 4, 0] 적합도= 686
# 염색체 # 2 = [7, 4, 0, 1, 3, 6, 8, 2, 5] 적합도= 583
# 염색체 # 3 = [4, 1, 3, 6, 5, 2, 7, 8, 0] 적합도= 412
# 염색체 # 4 = [3, 1, 0, 8, 4, 5, 2, 6, 7] 적합도= 404
# 염색체 # 5 = [8, 7, 4, 0, 5, 6, 1, 3, 2] 적합도= 337
# 염색체 # 6 = [7, 3, 6, 5, 2, 4, 1, 0, 8] 적합도= 327
# 염색체 # 7 = [0, 6, 3, 7, 5, 8, 2, 4, 1] 적합도= 282
# 염색체 # 8 = [8, 1, 6, 0, 4, 3, 2, 7, 5] 적합도= 257
# 염색체 # 9 = [6, 5, 3, 0, 7, 4, 2, 1, 8] 적합도= 216
# 염색체 # 10 = [2, 4, 1, 3, 7, 0, 8, 5, 6] 적합도= 178
# 염색체 # 11 = [7, 8, 0, 6, 4, 5, 2, 1, 3] 적합도= 116
# 염색체 # 12 = [5, 2, 1, 3, 8, 4, 6, 0, 7] 적합도= 56
# 염색체 # 13 = [8, 0, 7, 2, 3, 6, 4, 1, 5] 적합도= 1
# 염색체 # 14 = [1, 6, 2, 0, 7, 4, 8, 5, 3] 적합도= 1
# 염색체 # 15 = [0, 5, 1, 3, 8, 2, 6, 4, 7] 적합도= 1
#
# 세대 번호= 1
# 염색체 # 0 = [6, 7, 5, 2, 8, 0, 3, 1, 4] 적합도= 751
# 염색체 # 1 = [6, 7, 5, 2, 8, 0, 3, 1, 4] 적합도= 751
# 염색체 # 2 = [6, 8, 0, 1, 4, 3, 2, 7, 5] 적합도= 684
# 염색체 # 3 = [1, 0, 4, 3, 7, 6, 8, 2, 5] 적합도= 640
# 염색체 # 4 = [0, 3, 6, 5, 2, 4, 7, 8, 1] 적합도= 497
# 염색체 # 5 = [8, 6, 2, 7, 5, 0, 3, 1, 4] 적합도= 381
# 염색체 # 6 = [8, 7, 4, 0, 5, 6, 1, 3, 2] 적합도= 337
# 염색체 # 7 = [8, 1, 7, 6, 2, 5, 3, 4, 0] 적합도= 316
# 염색체 # 8 = [4, 0, 1, 6, 8, 3, 2, 7, 5] 적합도= 314
# 염색체 # 9 = [1, 8, 6, 0, 4, 3, 2, 7, 5] 적합도= 276
# 염색체 # 10 = [2, 6, 3, 7, 5, 8, 4, 1, 0] 적합도= 261
# 염색체 # 11 = [8, 1, 6, 0, 4, 3, 2, 7, 5] 적합도= 257
# 염색체 # 12 = [8, 1, 3, 6, 0, 4, 2, 7, 5] 적합도= 244
# 염색체 # 13 = [6, 3, 0, 7, 5, 8, 2, 4, 1] 적합도= 223
# 염색체 # 14 = [7, 8, 1, 6, 2, 5, 3, 4, 0] 적합도= 120
# 염색체 # 15 = [4, 1, 6, 3, 5, 2, 7, 8, 0] 적합도= 35
#
# 세대 번호= 2
# 염색체 # 0 = [6, 7, 5, 2, 8, 0, 1, 4, 3] 적합도= 753
# 염색체 # 1 = [1, 0, 4, 3, 7, 6, 8, 2, 5] 적합도= 640
# 염색체 # 2 = [0, 3, 6, 5, 2, 4, 7, 8, 1] 적합도= 497
# 염색체 # 3 = [6, 8, 0, 1, 4, 3, 7, 5, 2] 적합도= 496
# 염색체 # 4 = [6, 4, 5, 2, 8, 0, 3, 1, 7] 적합도= 490
# 염색체 # 5 = [8, 6, 2, 7, 5, 0, 3, 4, 1] 적합도= 467
# 염색체 # 6 = [4, 6, 2, 7, 5, 0, 1, 8, 3] 적합도= 372
# 염색체 # 7 = [4, 0, 1, 6, 7, 3, 2, 5, 8] 적합도= 351
# 염색체 # 8 = [8, 7, 4, 0, 5, 6, 1, 3, 2] 적합도= 337
# 염색체 # 9 = [4, 0, 1, 6, 8, 3, 2, 7, 5] 적합도= 314
# 염색체 # 10 = [4, 0, 1, 6, 8, 3, 2, 7, 5] 적합도= 314
# 염색체 # 11 = [8, 4, 3, 5, 6, 1, 0, 7, 2] 적합도= 274
# 염색체 # 12 = [4, 0, 1, 6, 8, 3, 7, 5, 2] 적합도= 253
# 염색체 # 13 = [8, 7, 4, 0, 5, 6, 1, 2, 3] 적합도= 130
# 염색체 # 14 = [0, 3, 6, 5, 2, 4, 7, 1, 8] 적합도= 127
# 염색체 # 15 = [8, 1, 6, 0, 4, 2, 7, 3, 5] 적합도= 1
#
# 세대 번호= 3
# 염색체 # 0 = [6, 7, 5, 2, 8, 0, 1, 4, 3] 적합도= 753
# 염색체 # 1 = [1, 0, 4, 3, 7, 6, 8, 2, 5] 적합도= 640
# 염색체 # 2 = [1, 0, 4, 3, 7, 6, 8, 2, 5] 적합도= 640
# 염색체 # 3 = [6, 7, 5, 4, 2, 8, 0, 3, 1] 적합도= 582
# 염색체 # 4 = [6, 4, 5, 7, 2, 8, 0, 1, 3] 적합도= 451
# 염색체 # 5 = [8, 4, 5, 6, 7, 3, 2, 1, 0] 적합도= 434
# 염색체 # 6 = [4, 6, 2, 7, 5, 0, 1, 8, 3] 적합도= 372
# 염색체 # 7 = [0, 1, 6, 8, 4, 3, 7, 5, 2] 적합도= 357
# 염색체 # 8 = [8, 7, 4, 0, 5, 6, 1, 3, 2] 적합도= 337
# 염색체 # 9 = [8, 7, 4, 0, 5, 6, 1, 3, 2] 적합도= 337
# 염색체 # 10 = [8, 7, 4, 0, 5, 6, 1, 3, 2] 적합도= 337
# 염색체 # 11 = [1, 7, 5, 2, 8, 0, 6, 4, 3] 적합도= 329
# 염색체 # 12 = [4, 0, 1, 6, 8, 3, 2, 7, 5] 적합도= 314
# 염색체 # 13 = [4, 0, 1, 6, 8, 3, 7, 5, 2] 적합도= 253
# 염색체 # 14 = [6, 0, 1, 4, 7, 3, 2, 5, 8] 적합도= 208
# 염색체 # 15 = [4, 7, 3, 5, 6, 1, 0, 2, 8] 적합도= 151
#
# 세대 번호= 4
# 염색체 # 0 = [4, 6, 7, 5, 2, 8, 0, 1, 3] 적합도= 892
# 염색체 # 1 = [6, 7, 5, 2, 8, 0, 3, 4, 1] 적합도= 686
# 염색체 # 2 = [6, 7, 5, 4, 2, 8, 0, 3, 1] 적합도= 582
# 염색체 # 3 = [1, 0, 4, 2, 8, 3, 7, 6, 5] 적합도= 494
# 염색체 # 4 = [1, 4, 3, 2, 8, 0, 7, 6, 5] 적합도= 467
# 염색체 # 5 = [5, 0, 1, 4, 7, 6, 8, 2, 3] 적합도= 466
# 염색체 # 6 = [6, 7, 0, 1, 8, 3, 2, 4, 5] 적합도= 405
# 염색체 # 7 = [6, 5, 2, 3, 7, 8, 0, 1, 4] 적합도= 405
# 염색체 # 8 = [3, 7, 6, 2, 8, 0, 1, 4, 5] 적합도= 391
# 염색체 # 9 = [1, 5, 2, 3, 7, 6, 8, 0, 4] 적합도= 274
# 염색체 # 10 = [0, 7, 5, 2, 8, 1, 6, 3, 4] 적합도= 228
# 염색체 # 11 = [2, 6, 4, 7, 5, 0, 1, 8, 3] 적합도= 214
# 염색체 # 12 = [6, 5, 0, 7, 2, 8, 1, 4, 3] 적합도= 212
# 염색체 # 13 = [7, 5, 1, 2, 8, 0, 6, 4, 3] 적합도= 177
# 염색체 # 14 = [4, 7, 3, 5, 6, 1, 0, 2, 8] 적합도= 151
# 염색체 # 15 = [7, 4, 5, 2, 8, 0, 6, 1, 3] 적합도= 1
#
# 세대 번호= 5
# 염색체 # 0 = [2, 7, 6, 5, 8, 1, 3, 4, 0] 적합도= 776
# 염색체 # 1 = [0, 6, 7, 5, 2, 8, 1, 3, 4] 적합도= 709
# 염색체 # 2 = [6, 5, 2, 3, 1, 0, 8, 4, 7] 적합도= 599
# 염색체 # 3 = [6, 7, 0, 1, 8, 3, 4, 2, 5] 적합도= 570
# 염색체 # 4 = [1, 0, 4, 2, 8, 3, 6, 7, 5] 적합도= 507
# 염색체 # 5 = [1, 0, 4, 2, 8, 3, 7, 6, 5] 적합도= 494
# 염색체 # 6 = [2, 3, 4, 1, 8, 0, 5, 6, 7] 적합도= 486
# 염색체 # 7 = [5, 0, 1, 4, 7, 6, 8, 2, 3] 적합도= 466
# 염색체 # 8 = [2, 6, 4, 7, 5, 8, 0, 3, 1] 적합도= 463
# 염색체 # 9 = [6, 7, 5, 4, 2, 0, 1, 8, 3] 적합도= 453
# 염색체 # 10 = [6, 7, 0, 1, 8, 3, 2, 4, 5] 적합도= 405
# 염색체 # 11 = [1, 0, 4, 2, 6, 5, 3, 7, 8] 적합도= 352
# 염색체 # 12 = [1, 7, 5, 2, 8, 0, 3, 4, 6] 적합도= 347
# 염색체 # 13 = [4, 7, 0, 1, 8, 3, 6, 2, 5] 적합도= 9
# 염색체 # 14 = [3, 6, 2, 0, 7, 8, 1, 4, 5] 적합도= 1
# 염색체 # 15 = [8, 5, 2, 3, 6, 0, 7, 1, 4] 적합도= 1
#
# 세대 번호= 6
# 염색체 # 0 = [6, 7, 0, 1, 2, 8, 3, 4, 5] 적합도= 657
# 염색체 # 1 = [6, 7, 5, 4, 8, 2, 0, 1, 3] 적합도= 642
# 염색체 # 2 = [6, 7, 5, 2, 0, 1, 8, 4, 3] 적합도= 623
# 염색체 # 3 = [6, 7, 0, 1, 3, 2, 4, 8, 5] 적합도= 570
# 염색체 # 4 = [1, 0, 4, 2, 8, 3, 7, 6, 5] 적합도= 494
# 염색체 # 5 = [1, 0, 4, 2, 8, 3, 7, 6, 5] 적합도= 494
# 염색체 # 6 = [2, 5, 0, 1, 8, 3, 4, 6, 7] 적합도= 487
# 염색체 # 7 = [5, 0, 1, 4, 6, 7, 8, 3, 2] 적합도= 473
# 염색체 # 8 = [6, 7, 0, 1, 4, 5, 8, 2, 3] 적합도= 446
# 염색체 # 9 = [1, 5, 0, 4, 7, 6, 8, 2, 3] 적합도= 412
# 염색체 # 10 = [5, 1, 7, 2, 8, 0, 3, 4, 6] 적합도= 351
# 염색체 # 11 = [1, 7, 5, 2, 8, 0, 3, 4, 6] 적합도= 347
# 염색체 # 12 = [1, 0, 7, 6, 8, 3, 2, 4, 5] 적합도= 264
# 염색체 # 13 = [6, 7, 0, 1, 5, 4, 8, 2, 3] 적합도= 230
# 염색체 # 14 = [7, 3, 4, 1, 8, 0, 5, 6, 2] 적합도= 190
# 염색체 # 15 = [7, 0, 4, 2, 8, 3, 6, 1, 5] 적합도= 1
#
# 세대 번호= 7
# 염색체 # 0 = [6, 7, 5, 2, 0, 1, 8, 3, 4] 적합도= 696
# 염색체 # 1 = [6, 7, 0, 1, 2, 8, 3, 4, 5] 적합도= 657
# 염색체 # 2 = [5, 7, 0, 1, 2, 8, 3, 4, 6] 적합도= 579
# 염색체 # 3 = [6, 7, 0, 1, 3, 2, 4, 8, 5] 적합도= 570
# 염색체 # 4 = [6, 7, 0, 1, 3, 2, 4, 8, 5] 적합도= 570
# 염색체 # 5 = [6, 7, 0, 1, 3, 2, 4, 5, 8] 적합도= 546
# 염색체 # 6 = [2, 0, 1, 4, 6, 7, 8, 3, 5] 적합도= 505
# 염색체 # 7 = [2, 5, 0, 1, 8, 3, 4, 6, 7] 적합도= 487
# 염색체 # 8 = [5, 2, 1, 4, 6, 7, 8, 3, 0] 적합도= 461
# 염색체 # 9 = [6, 7, 0, 1, 4, 5, 8, 2, 3] 적합도= 446
# 염색체 # 10 = [1, 6, 5, 2, 8, 0, 3, 4, 7] 적합도= 324
# 염색체 # 11 = [6, 7, 8, 1, 5, 4, 0, 2, 3] 적합도= 299
# 염색체 # 12 = [1, 0, 8, 7, 3, 2, 4, 6, 5] 적합도= 270
# 염색체 # 13 = [6, 0, 1, 2, 8, 3, 7, 4, 5] 적합도= 215
# 염색체 # 14 = [5, 1, 7, 2, 8, 0, 3, 6, 4] 적합도= 18
# 염색체 # 15 = [6, 7, 0, 8, 4, 5, 1, 2, 3] 적합도= 1
#
# 세대 번호= 8
# 염색체 # 0 = [6, 7, 0, 1, 3, 2, 8, 4, 5] 적합도= 594
# 염색체 # 1 = [5, 7, 0, 1, 2, 8, 3, 4, 6] 적합도= 579
# 염색체 # 2 = [6, 7, 0, 1, 3, 2, 4, 5, 8] 적합도= 546
# 염색체 # 3 = [5, 7, 0, 1, 2, 3, 4, 8, 6] 적합도= 545
# 염색체 # 4 = [2, 0, 1, 4, 6, 7, 3, 5, 8] 적합도= 502
# 염색체 # 5 = [2, 0, 6, 7, 1, 3, 4, 5, 8] 적합도= 481
# 염색체 # 6 = [6, 7, 2, 0, 1, 4, 8, 3, 5] 적합도= 462
# 염색체 # 7 = [6, 7, 1, 5, 2, 8, 0, 3, 4] 적합도= 459
# 염색체 # 8 = [4, 7, 0, 1, 5, 6, 8, 2, 3] 적합도= 438
# 염색체 # 9 = [1, 6, 7, 0, 4, 5, 8, 2, 3] 적합도= 379
# 염색체 # 10 = [6, 2, 0, 1, 3, 7, 4, 8, 5] 적합도= 377
# 염색체 # 11 = [1, 6, 5, 2, 8, 0, 3, 4, 7] 적합도= 324
# 염색체 # 12 = [6, 7, 8, 1, 5, 4, 0, 2, 3] 적합도= 299
# 염색체 # 13 = [6, 7, 8, 1, 4, 5, 0, 2, 3] 적합도= 279
# 염색체 # 14 = [6, 2, 1, 4, 7, 0, 3, 8, 5] 적합도= 264
# 염색체 # 15 = [5, 7, 0, 1, 2, 4, 6, 8, 3] 적합도= 228
#
# 세대 번호= 9
# 염색체 # 0 = [6, 5, 0, 1, 2, 8, 3, 4, 7] 적합도= 671
# 염색체 # 1 = [5, 7, 6, 0, 1, 2, 8, 3, 4] 적합도= 662
# 염색체 # 2 = [5, 7, 0, 1, 2, 8, 3, 4, 6] 적합도= 579
# 염색체 # 3 = [5, 7, 0, 1, 2, 8, 3, 4, 6] 적합도= 579
# 염색체 # 4 = [6, 7, 0, 1, 3, 2, 4, 5, 8] 적합도= 546
# 염색체 # 5 = [5, 7, 0, 1, 2, 3, 4, 8, 6] 적합도= 545
# 염색체 # 6 = [6, 7, 1, 3, 2, 8, 0, 4, 5] 적합도= 519
# 염색체 # 7 = [5, 7, 0, 1, 3, 2, 8, 4, 6] 적합도= 516
# 염색체 # 8 = [5, 7, 0, 1, 8, 3, 4, 2, 6] 적합도= 455
# 염색체 # 9 = [6, 7, 8, 1, 4, 5, 0, 2, 3] 적합도= 279
# 염색체 # 10 = [7, 0, 1, 4, 6, 5, 2, 8, 3] 적합도= 269
# 염색체 # 11 = [6, 7, 1, 5, 0, 2, 8, 3, 4] 적합도= 231
# 염색체 # 12 = [5, 7, 0, 1, 2, 4, 6, 8, 3] 적합도= 228
# 염색체 # 13 = [2, 6, 0, 7, 1, 3, 4, 5, 8] 적합도= 150
# 염색체 # 14 = [2, 0, 6, 7, 1, 3, 8, 4, 5] 적합도= 125
# 염색체 # 15 = [0, 7, 1, 5, 2, 4, 6, 3, 8] 적합도= 1
#
# 세대 번호= 10
# 염색체 # 0 = [5, 7, 6, 0, 1, 2, 8, 3, 4] 적합도= 662
# 염색체 # 1 = [6, 7, 0, 1, 2, 8, 3, 4, 5] 적합도= 657
# 염색체 # 2 = [4, 7, 6, 0, 1, 2, 8, 5, 3] 적합도= 578
# 염색체 # 3 = [6, 7, 1, 0, 3, 2, 4, 5, 8] 적합도= 567
# 염색체 # 4 = [6, 7, 0, 1, 3, 2, 4, 5, 8] 적합도= 546
# 염색체 # 5 = [5, 7, 1, 0, 2, 3, 4, 8, 6] 적합도= 536
# 염색체 # 6 = [7, 0, 1, 8, 3, 2, 4, 5, 6] 적합도= 405
# 염색체 # 7 = [6, 7, 8, 1, 4, 5, 0, 2, 3] 적합도= 279
# 염색체 # 8 = [6, 2, 0, 7, 1, 3, 4, 5, 8] 적합도= 232
# 염색체 # 9 = [7, 1, 5, 0, 3, 2, 8, 4, 6] 적합도= 198
# 염색체 # 10 = [6, 7, 1, 3, 2, 5, 0, 8, 4] 적합도= 169
# 염색체 # 11 = [6, 5, 0, 1, 2, 7, 3, 8, 4] 적합도= 135
# 염색체 # 12 = [2, 0, 6, 7, 1, 4, 8, 3, 5] 적합도= 7
# 염색체 # 13 = [6, 7, 1, 8, 4, 5, 0, 2, 3] 적합도= 5
# 염색체 # 14 = [1, 6, 0, 5, 2, 8, 3, 4, 7] 적합도= 1
# 염색체 # 15 = [7, 1, 8, 4, 6, 5, 0, 2, 3] 적합도= 1
#
# 세대 번호= 11
# 염색체 # 0 = [5, 7, 6, 0, 1, 2, 8, 3, 4] 적합도= 662
# 염색체 # 1 = [6, 7, 0, 1, 2, 8, 3, 4, 5] 적합도= 657
# 염색체 # 2 = [7, 5, 1, 0, 2, 3, 4, 8, 6] 적합도= 650
# 염색체 # 3 = [7, 6, 1, 0, 3, 2, 4, 5, 8] 적합도= 606
# 염색체 # 4 = [6, 7, 0, 1, 3, 2, 8, 4, 5] 적합도= 594
# 염색체 # 5 = [6, 7, 1, 0, 3, 2, 4, 8, 5] 적합도= 591
# 염색체 # 6 = [7, 6, 0, 1, 3, 2, 4, 5, 8] 적합도= 588
# 염색체 # 7 = [6, 7, 1, 0, 3, 2, 4, 5, 8] 적합도= 567
# 염색체 # 8 = [5, 7, 1, 0, 2, 3, 4, 8, 6] 적합도= 536
# 염색체 # 9 = [8, 7, 0, 1, 3, 2, 4, 5, 6] 적합도= 490
# 염색체 # 10 = [4, 7, 8, 6, 0, 1, 2, 5, 3] 적합도= 393
# 염색체 # 11 = [6, 7, 0, 4, 1, 2, 8, 5, 3] 적합도= 316
# 염색체 # 12 = [7, 1, 5, 0, 2, 3, 4, 8, 6] 적합도= 197
# 염색체 # 13 = [7, 0, 6, 1, 2, 8, 3, 4, 5] 적합도= 96
# 염색체 # 14 = [6, 0, 8, 1, 4, 5, 7, 3, 2] 적합도= 23
# 염색체 # 15 = [7, 1, 6, 8, 4, 5, 0, 2, 3] 적합도= 1
#
# 세대 번호= 12
# 염색체 # 0 = [7, 6, 0, 1, 2, 8, 3, 4, 5] 적합도= 662
# 염색체 # 1 = [7, 5, 1, 0, 2, 3, 4, 8, 6] 적합도= 650
# 염색체 # 2 = [7, 6, 0, 1, 2, 8, 4, 3, 5] 적합도= 610
# 염색체 # 3 = [6, 7, 0, 1, 3, 2, 8, 4, 5] 적합도= 594
# 염색체 # 4 = [7, 6, 1, 0, 3, 2, 4, 8, 5] 적합도= 593
# 염색체 # 5 = [6, 7, 1, 0, 3, 2, 4, 8, 5] 적합도= 591
# 염색체 # 6 = [6, 7, 0, 1, 3, 2, 4, 8, 5] 적합도= 570
# 염색체 # 7 = [6, 7, 1, 0, 3, 2, 4, 5, 8] 적합도= 567
# 염색체 # 8 = [7, 0, 1, 3, 2, 5, 4, 8, 6] 적합도= 465
# 염색체 # 9 = [6, 7, 0, 4, 1, 2, 8, 3, 5] 적합도= 398
# 염색체 # 10 = [4, 7, 8, 6, 0, 1, 2, 5, 3] 적합도= 393
# 염색체 # 11 = [4, 7, 8, 6, 0, 1, 2, 5, 3] 적합도= 393
# 염색체 # 12 = [7, 6, 0, 1, 2, 3, 8, 5, 4] 적합도= 360
# 염색체 # 13 = [7, 1, 0, 2, 3, 6, 8, 4, 5] 적합도= 203
# 염색체 # 14 = [7, 1, 5, 0, 2, 3, 4, 8, 6] 적합도= 197
# 염색체 # 15 = [7, 8, 3, 6, 0, 1, 2, 5, 4] 적합도= 136
#
# 세대 번호= 13
# 염색체 # 0 = [6, 7, 0, 1, 3, 4, 8, 2, 5] 적합도= 759
# 염색체 # 1 = [6, 7, 0, 1, 2, 8, 3, 4, 5] 적합도= 657
# 염색체 # 2 = [7, 5, 1, 0, 2, 3, 4, 8, 6] 적합도= 650
# 염색체 # 3 = [7, 6, 1, 0, 3, 2, 8, 4, 5] 적합도= 617
# 염색체 # 4 = [6, 7, 0, 1, 3, 2, 8, 4, 5] 적합도= 594
# 염색체 # 5 = [7, 6, 1, 0, 3, 2, 4, 8, 5] 적합도= 593
# 염색체 # 6 = [6, 7, 1, 0, 3, 2, 4, 8, 5] 적합도= 591
# 염색체 # 7 = [6, 7, 1, 0, 3, 2, 4, 8, 5] 적합도= 591
# 염색체 # 8 = [7, 1, 0, 2, 5, 3, 4, 8, 6] 적합도= 467
# 염색체 # 9 = [4, 7, 8, 6, 0, 1, 2, 5, 3] 적합도= 393
# 염색체 # 10 = [4, 7, 8, 6, 0, 1, 3, 2, 5] 적합도= 382
# 염색체 # 11 = [7, 1, 0, 3, 6, 2, 4, 8, 5] 적합도= 308
# 염색체 # 12 = [3, 7, 8, 6, 0, 1, 5, 2, 4] 적합도= 283
# 염색체 # 13 = [7, 6, 0, 1, 2, 8, 4, 5, 3] 적합도= 264
# 염색체 # 14 = [4, 7, 8, 6, 0, 1, 2, 3, 5] 적합도= 228
# 염색체 # 15 = [7, 1, 5, 0, 2, 3, 4, 8, 6] 적합도= 197
#
# 세대 번호= 14
# 염색체 # 0 = [7, 8, 1, 0, 2, 3, 4, 6, 5] 적합도= 726
# 염색체 # 1 = [7, 6, 1, 0, 2, 8, 3, 4, 5] 적합도= 650
# 염색체 # 2 = [6, 7, 0, 1, 8, 2, 4, 3, 5] 적합도= 623
# 염색체 # 3 = [6, 8, 1, 0, 3, 5, 2, 4, 7] 적합도= 559
# 염색체 # 4 = [5, 7, 4, 1, 2, 3, 0, 8, 6] 적합도= 514
# 염색체 # 5 = [7, 5, 8, 6, 0, 1, 3, 2, 4] 적합도= 450
# 염색체 # 6 = [4, 6, 1, 0, 3, 2, 7, 8, 5] 적합도= 408
# 염색체 # 7 = [7, 5, 1, 0, 2, 6, 3, 4, 8] 적합도= 404
# 염색체 # 8 = [4, 7, 8, 6, 0, 1, 3, 2, 5] 적합도= 382
# 염색체 # 9 = [7, 1, 0, 3, 6, 2, 4, 8, 5] 적합도= 308
# 염색체 # 10 = [3, 7, 8, 6, 0, 1, 5, 2, 4] 적합도= 283
# 염색체 # 11 = [3, 7, 8, 6, 0, 1, 5, 2, 4] 적합도= 283
# 염색체 # 12 = [3, 7, 8, 6, 0, 1, 2, 4, 5] 적합도= 160
# 염색체 # 13 = [6, 7, 0, 4, 8, 1, 2, 5, 3] 적합도= 112
# 염색체 # 14 = [7, 1, 0, 6, 3, 2, 4, 8, 5] 적합도= 97
# 염색체 # 15 = [6, 5, 1, 7, 0, 3, 2, 8, 4] 적합도= 83
#
# 세대 번호= 15
# 염색체 # 0 = [7, 8, 1, 0, 2, 3, 4, 6, 5] 적합도= 726
# 염색체 # 1 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 2 = [7, 5, 1, 0, 2, 3, 4, 6, 8] 적합도= 585
# 염색체 # 3 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 4 = [6, 5, 1, 0, 3, 2, 7, 8, 4] 적합도= 451
# 염색체 # 5 = [6, 7, 1, 0, 3, 5, 2, 4, 8] 적합도= 429
# 염색체 # 6 = [7, 5, 1, 0, 2, 6, 3, 4, 8] 적합도= 404
# 염색체 # 7 = [7, 1, 0, 2, 6, 3, 4, 8, 5] 적합도= 346
# 염색체 # 8 = [6, 0, 1, 7, 2, 8, 3, 4, 5] 적합도= 329
# 염색체 # 9 = [7, 3, 4, 6, 0, 1, 5, 2, 8] 적합도= 322
# 염색체 # 10 = [3, 7, 8, 6, 0, 1, 5, 2, 4] 적합도= 283
# 염색체 # 11 = [3, 7, 6, 0, 1, 8, 4, 5, 2] 적합도= 234
# 염색체 # 12 = [5, 7, 0, 4, 8, 1, 2, 3, 6] 적합도= 181
# 염색체 # 13 = [6, 5, 1, 0, 7, 3, 2, 8, 4] 적합도= 139
# 염색체 # 14 = [6, 5, 1, 0, 2, 7, 3, 8, 4] 적합도= 125
# 염색체 # 15 = [6, 1, 2, 7, 0, 8, 3, 4, 5] 적합도= 89
#
# 세대 번호= 16
# 염색체 # 0 = [7, 8, 1, 0, 2, 3, 4, 6, 5] 적합도= 726
# 염색체 # 1 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 2 = [7, 5, 1, 0, 2, 3, 4, 6, 8] 적합도= 585
# 염색체 # 3 = [7, 1, 0, 2, 3, 4, 5, 6, 8] 적합도= 549
# 염색체 # 4 = [7, 1, 0, 2, 3, 4, 6, 8, 5] 적합도= 527
# 염색체 # 5 = [7, 5, 1, 0, 3, 2, 8, 6, 4] 적합도= 526
# 염색체 # 6 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [6, 5, 1, 0, 3, 2, 7, 8, 4] 적합도= 451
# 염색체 # 8 = [7, 5, 8, 6, 0, 1, 3, 2, 4] 적합도= 450
# 염색체 # 9 = [6, 0, 1, 7, 2, 8, 3, 4, 5] 적합도= 329
# 염색체 # 10 = [6, 0, 1, 7, 2, 8, 5, 4, 3] 적합도= 247
# 염색체 # 11 = [3, 7, 6, 0, 1, 8, 4, 5, 2] 적합도= 234
# 염색체 # 12 = [7, 3, 4, 6, 0, 5, 1, 2, 8] 적합도= 94
# 염색체 # 13 = [5, 3, 8, 6, 0, 1, 2, 7, 4] 적합도= 90
# 염색체 # 14 = [6, 1, 2, 7, 0, 8, 3, 4, 5] 적합도= 89
# 염색체 # 15 = [5, 7, 0, 4, 8, 1, 6, 2, 3] 적합도= 1
#
# 세대 번호= 17
# 염색체 # 0 = [7, 8, 1, 0, 2, 3, 4, 6, 5] 적합도= 726
# 염색체 # 1 = [7, 8, 1, 0, 2, 3, 4, 6, 5] 적합도= 726
# 염색체 # 2 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 3 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 4 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 5 = [7, 1, 0, 2, 3, 4, 5, 6, 8] 적합도= 549
# 염색체 # 6 = [7, 1, 2, 0, 3, 4, 5, 6, 8] 적합도= 537
# 염색체 # 7 = [7, 1, 0, 2, 3, 4, 6, 8, 5] 적합도= 527
# 염색체 # 8 = [7, 1, 0, 2, 3, 4, 6, 8, 5] 적합도= 527
# 염색체 # 9 = [7, 5, 1, 0, 3, 2, 8, 6, 4] 적합도= 526
# 염색체 # 10 = [7, 5, 1, 3, 0, 2, 8, 6, 4] 적합도= 484
# 염색체 # 11 = [7, 5, 1, 0, 8, 2, 6, 3, 4] 적합도= 390
# 염색체 # 12 = [6, 0, 1, 7, 2, 8, 3, 4, 5] 적합도= 329
# 염색체 # 13 = [7, 8, 1, 0, 5, 3, 2, 6, 4] 적합도= 175
# 염색체 # 14 = [7, 0, 8, 6, 5, 1, 3, 2, 4] 적합도= 133
# 염색체 # 15 = [7, 8, 1, 3, 2, 6, 0, 5, 4] 적합도= 69
#
# 세대 번호= 18
# 염색체 # 0 = [7, 8, 1, 0, 3, 4, 5, 2, 6] 적합도= 804
# 염색체 # 1 = [7, 8, 1, 0, 2, 3, 4, 5, 6] 적합도= 804
# 염색체 # 2 = [7, 8, 1, 2, 0, 3, 4, 6, 5] 적합도= 714
# 염색체 # 3 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 4 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 5 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 6 = [7, 8, 1, 0, 2, 5, 6, 3, 4] 적합도= 535
# 염색체 # 7 = [7, 5, 8, 6, 0, 1, 2, 3, 4] 적합도= 518
# 염색체 # 8 = [7, 1, 2, 0, 3, 4, 6, 8, 5] 적합도= 515
# 염색체 # 9 = [7, 5, 8, 6, 0, 1, 3, 2, 4] 적합도= 450
# 염색체 # 10 = [7, 8, 1, 0, 5, 6, 3, 4, 2] 적합도= 439
# 염색체 # 11 = [7, 1, 0, 5, 2, 3, 4, 6, 8] 적합도= 370
# 염색체 # 12 = [7, 5, 0, 2, 3, 4, 6, 8, 1] 적합도= 236
# 염색체 # 13 = [7, 5, 8, 1, 0, 6, 3, 2, 4] 적합도= 227
# 염색체 # 14 = [7, 1, 2, 0, 3, 5, 8, 6, 4] 적합도= 180
# 염색체 # 15 = [0, 5, 1, 7, 8, 2, 3, 4, 6] 적합도= 50
#
# 세대 번호= 19
# 염색체 # 0 = [7, 8, 1, 2, 0, 3, 4, 5, 6] 적합도= 792
# 염색체 # 1 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 2 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 3 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 4 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 5 = [7, 8, 1, 0, 2, 5, 6, 3, 4] 적합도= 535
# 염색체 # 6 = [7, 8, 1, 0, 2, 5, 6, 3, 4] 적합도= 535
# 염색체 # 7 = [7, 1, 2, 0, 3, 4, 6, 8, 5] 적합도= 515
# 염색체 # 8 = [7, 1, 0, 3, 2, 4, 6, 8, 5] 적합도= 489
# 염색체 # 9 = [7, 5, 8, 6, 0, 1, 3, 2, 4] 적합도= 450
# 염색체 # 10 = [7, 8, 1, 0, 5, 6, 3, 4, 2] 적합도= 439
# 염색체 # 11 = [7, 5, 8, 2, 0, 3, 6, 1, 4] 적합도= 326
# 염색체 # 12 = [7, 5, 0, 2, 3, 4, 6, 8, 1] 적합도= 236
# 염색체 # 13 = [1, 0, 3, 7, 8, 4, 5, 2, 6] 적합도= 229
# 염색체 # 14 = [7, 4, 8, 0, 2, 5, 6, 3, 1] 적합도= 79
# 염색체 # 15 = [5, 1, 7, 0, 3, 8, 2, 4, 6] 적합도= 78
#
# 세대 번호= 20
# 염색체 # 0 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 1 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 2 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 3 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 4 = [7, 8, 1, 0, 2, 5, 6, 3, 4] 적합도= 535
# 염색체 # 5 = [7, 8, 1, 0, 2, 5, 6, 3, 4] 적합도= 535
# 염색체 # 6 = [7, 8, 1, 0, 2, 5, 6, 3, 4] 적합도= 535
# 염색체 # 7 = [7, 1, 0, 2, 3, 4, 6, 8, 5] 적합도= 527
# 염색체 # 8 = [7, 8, 2, 0, 1, 5, 6, 3, 4] 적합도= 523
# 염색체 # 9 = [7, 8, 2, 6, 0, 3, 1, 4, 5] 적합도= 521
# 염색체 # 10 = [7, 5, 8, 6, 0, 1, 2, 3, 4] 적합도= 518
# 염색체 # 11 = [2, 5, 8, 6, 0, 1, 3, 4, 7] 적합도= 495
# 염색체 # 12 = [7, 8, 0, 2, 6, 1, 3, 4, 5] 적합도= 413
# 염색체 # 13 = [7, 4, 1, 0, 2, 5, 6, 3, 8] 적합도= 383
# 염색체 # 14 = [7, 5, 8, 2, 0, 3, 6, 1, 4] 적합도= 326
# 염색체 # 15 = [7, 1, 8, 6, 0, 5, 3, 2, 4] 적합도= 1
#
# 세대 번호= 21
# 염색체 # 0 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 1 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 2 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 3 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 4 = [7, 5, 8, 6, 0, 1, 3, 4, 2] 적합도= 608
# 염색체 # 5 = [7, 8, 6, 3, 0, 1, 2, 4, 5] 적합도= 568
# 염색체 # 6 = [7, 8, 1, 0, 2, 5, 6, 3, 4] 적합도= 535
# 염색체 # 7 = [7, 2, 8, 0, 1, 3, 6, 4, 5] 적합도= 451
# 염색체 # 8 = [7, 5, 8, 6, 0, 1, 3, 2, 4] 적합도= 450
# 염색체 # 9 = [7, 4, 2, 6, 0, 1, 3, 8, 5] 적합도= 342
# 염색체 # 10 = [7, 8, 2, 5, 0, 1, 6, 3, 4] 적합도= 310
# 염색체 # 11 = [7, 8, 2, 6, 0, 1, 5, 3, 4] 적합도= 296
# 염색체 # 12 = [7, 2, 1, 6, 8, 5, 0, 3, 4] 적합도= 285
# 염색체 # 13 = [2, 5, 8, 6, 0, 1, 7, 3, 4] 적합도= 225
# 염색체 # 14 = [7, 8, 2, 0, 1, 5, 3, 6, 4] 적합도= 211
# 염색체 # 15 = [7, 8, 0, 2, 6, 1, 3, 5, 4] 적합도= 78
#
# 세대 번호= 22
# 염색체 # 0 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 1 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 2 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 3 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 4 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 5 = [7, 8, 2, 6, 4, 1, 3, 0, 5] 적합도= 553
# 염색체 # 6 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [7, 5, 8, 6, 0, 1, 2, 3, 4] 적합도= 518
# 염색체 # 8 = [7, 2, 8, 0, 1, 3, 6, 4, 5] 적합도= 451
# 염색체 # 9 = [7, 2, 6, 3, 0, 1, 8, 4, 5] 적합도= 350
# 염색체 # 10 = [4, 8, 2, 6, 0, 1, 3, 7, 5] 적합도= 303
# 염색체 # 11 = [7, 2, 8, 6, 0, 1, 5, 3, 4] 적합도= 266
# 염색체 # 12 = [7, 2, 8, 6, 0, 1, 5, 3, 4] 적합도= 266
# 염색체 # 13 = [7, 8, 6, 0, 5, 1, 3, 4, 2] 적합도= 213
# 염색체 # 14 = [7, 3, 8, 6, 0, 1, 2, 4, 5] 적합도= 199
# 염색체 # 15 = [3, 8, 2, 6, 0, 1, 7, 4, 5] 적합도= 1
#
# 세대 번호= 23
# 염색체 # 0 = [7, 5, 8, 6, 2, 0, 1, 3, 4] 적합도= 699
# 염색체 # 1 = [7, 8, 2, 6, 0, 1, 3, 4, 5] 적합도= 662
# 염색체 # 2 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 3 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 4 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 5 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 6 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 8 = [7, 8, 2, 0, 3, 1, 6, 4, 5] 적합도= 510
# 염색체 # 9 = [7, 8, 6, 0, 4, 1, 3, 2, 5] 적합도= 458
# 염색체 # 10 = [7, 5, 8, 6, 0, 3, 1, 2, 4] 적합도= 438
# 염색체 # 11 = [7, 8, 2, 0, 5, 6, 1, 3, 4] 적합도= 436
# 염색체 # 12 = [7, 8, 2, 6, 0, 1, 5, 3, 4] 적합도= 296
# 염색체 # 13 = [7, 8, 6, 0, 5, 1, 3, 4, 2] 적합도= 213
# 염색체 # 14 = [7, 2, 8, 6, 3, 1, 5, 0, 4] 적합도= 136
# 염색체 # 15 = [7, 1, 8, 6, 0, 2, 5, 3, 4] 적합도= 34
#
# 세대 번호= 24
# 염색체 # 0 = [7, 5, 8, 6, 2, 0, 1, 3, 4] 적합도= 699
# 염색체 # 1 = [7, 5, 8, 6, 2, 0, 1, 3, 4] 적합도= 699
# 염색체 # 2 = [7, 2, 8, 6, 0, 1, 3, 4, 5] 적합도= 632
# 염색체 # 3 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 4 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 5 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 6 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 8 = [7, 5, 8, 6, 0, 3, 1, 2, 4] 적합도= 438
# 염색체 # 9 = [7, 8, 6, 0, 2, 3, 1, 4, 5] 적합도= 392
# 염색체 # 10 = [7, 2, 8, 0, 1, 6, 3, 4, 5] 적합도= 386
# 염색체 # 11 = [7, 8, 2, 0, 6, 4, 1, 3, 5] 적합도= 374
# 염색체 # 12 = [7, 8, 2, 0, 3, 6, 1, 4, 5] 적합도= 371
# 염색체 # 13 = [7, 4, 2, 6, 0, 1, 3, 8, 5] 적합도= 342
# 염색체 # 14 = [7, 8, 2, 6, 0, 1, 5, 3, 4] 적합도= 296
# 염색체 # 15 = [7, 8, 2, 0, 5, 1, 6, 3, 4] 적합도= 72
#
# 세대 번호= 25
# 염색체 # 0 = [7, 5, 8, 6, 2, 0, 1, 3, 4] 적합도= 699
# 염색체 # 1 = [7, 8, 2, 0, 1, 3, 6, 4, 5] 적합도= 577
# 염색체 # 2 = [7, 5, 8, 6, 2, 0, 1, 4, 3] 적합도= 570
# 염색체 # 3 = [7, 8, 2, 0, 1, 6, 4, 3, 5] 적합도= 533
# 염색체 # 4 = [7, 5, 8, 6, 2, 4, 0, 1, 3] 적합도= 532
# 염색체 # 5 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 6 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 8 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 9 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 10 = [7, 5, 8, 6, 0, 3, 1, 2, 4] 적합도= 438
# 염색체 # 11 = [7, 8, 2, 0, 6, 1, 3, 4, 5] 적합도= 427
# 염색체 # 12 = [7, 8, 6, 0, 2, 1, 4, 3, 5] 적합도= 403
# 염색체 # 13 = [7, 8, 6, 0, 2, 3, 1, 4, 5] 적합도= 392
# 염색체 # 14 = [7, 4, 5, 6, 0, 1, 3, 8, 2] 적합도= 373
# 염색체 # 15 = [7, 4, 2, 6, 0, 5, 8, 1, 3] 적합도= 1
#
# 세대 번호= 26
# 염색체 # 0 = [7, 5, 8, 6, 2, 0, 1, 4, 3] 적합도= 570
# 염색체 # 1 = [7, 8, 2, 0, 1, 6, 4, 3, 5] 적합도= 533
# 염색체 # 2 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 3 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 4 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 5 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 6 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 8 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 9 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 10 = [7, 8, 6, 3, 2, 1, 0, 4, 5] 적합도= 507
# 염색체 # 11 = [7, 5, 8, 6, 0, 3, 1, 2, 4] 적합도= 438
# 염색체 # 12 = [7, 8, 2, 0, 6, 1, 3, 4, 5] 적합도= 427
# 염색체 # 13 = [7, 8, 0, 2, 1, 6, 3, 4, 5] 적합도= 275
# 염색체 # 14 = [3, 5, 8, 6, 2, 0, 1, 4, 7] 적합도= 235
# 염색체 # 15 = [0, 8, 2, 7, 1, 3, 6, 4, 5] 적합도= 1
#
# 세대 번호= 27
# 염색체 # 0 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 1 = [7, 5, 8, 6, 2, 0, 1, 4, 3] 적합도= 570
# 염색체 # 2 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 3 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 4 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 5 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 6 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 8 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 9 = [7, 8, 6, 3, 2, 1, 0, 4, 5] 적합도= 507
# 염색체 # 10 = [7, 2, 8, 6, 0, 3, 1, 4, 5] 적합도= 491
# 염색체 # 11 = [3, 5, 8, 6, 2, 7, 0, 1, 4] 적합도= 358
# 염색체 # 12 = [8, 6, 3, 5, 2, 0, 1, 4, 7] 적합도= 307
# 염색체 # 13 = [7, 8, 4, 0, 2, 6, 3, 1, 5] 적합도= 263
# 염색체 # 14 = [8, 6, 0, 7, 2, 1, 3, 4, 5] 적합도= 253
# 염색체 # 15 = [7, 5, 1, 0, 2, 6, 3, 8, 4] 적합도= 108
#
# 세대 번호= 28
# 염색체 # 0 = [7, 8, 6, 5, 2, 0, 1, 4, 3] 적합도= 629
# 염색체 # 1 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 2 = [7, 5, 8, 6, 2, 3, 1, 0, 4] 적합도= 600
# 염색체 # 3 = [7, 5, 8, 6, 2, 0, 1, 4, 3] 적합도= 570
# 염색체 # 4 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 5 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 6 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 7 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 8 = [7, 8, 1, 0, 2, 6, 3, 4, 5] 적합도= 521
# 염색체 # 9 = [7, 8, 1, 0, 2, 6, 5, 3, 4] 적합도= 519
# 염색체 # 10 = [7, 8, 6, 3, 2, 1, 0, 4, 5] 적합도= 507
# 염색체 # 11 = [7, 5, 1, 0, 2, 6, 8, 3, 4] 적합도= 417
# 염색체 # 12 = [8, 3, 5, 6, 2, 0, 1, 4, 7] 적합도= 367
# 염색체 # 13 = [7, 1, 8, 6, 5, 3, 0, 4, 2] 적합도= 266
# 염색체 # 14 = [8, 6, 0, 7, 2, 1, 3, 4, 5] 적합도= 253
# 염색체 # 15 = [7, 2, 8, 6, 0, 3, 5, 4, 1] 적합도= 112
#
# 세대 번호= 29
# 염색체 # 0 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 1 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 2 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 3 = [8, 6, 7, 0, 2, 1, 3, 4, 5] 적합도= 572
# 염색체 # 4 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 5 = [7, 8, 1, 0, 2, 6, 5, 3, 4] 적합도= 519
# 염색체 # 6 = [7, 8, 6, 3, 2, 1, 0, 4, 5] 적합도= 507
# 염색체 # 7 = [7, 8, 6, 3, 1, 2, 0, 4, 5] 적합도= 465
# 염색체 # 8 = [7, 8, 1, 0, 5, 6, 3, 4, 2] 적합도= 439
# 염색체 # 9 = [7, 5, 1, 0, 2, 6, 8, 3, 4] 적합도= 417
# 염색체 # 10 = [7, 5, 1, 8, 6, 2, 3, 0, 4] 적합도= 329
# 염색체 # 11 = [7, 4, 1, 0, 2, 6, 3, 8, 5] 적합도= 324
# 염색체 # 12 = [7, 8, 0, 3, 2, 1, 6, 4, 5] 적합도= 315
# 염색체 # 13 = [7, 8, 3, 0, 2, 6, 1, 4, 5] 적합도= 302
# 염색체 # 14 = [8, 1, 0, 7, 2, 6, 3, 4, 5] 적합도= 253
# 염색체 # 15 = [7, 1, 8, 0, 2, 6, 5, 3, 4] 적합도= 149
#
# 세대 번호= 30
# 염색체 # 0 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 1 = [7, 5, 8, 4, 2, 3, 0, 1, 6] 적합도= 593
# 염색체 # 2 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 3 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 4 = [7, 5, 1, 0, 2, 8, 6, 3, 4] 적합도= 486
# 염색체 # 5 = [7, 5, 6, 3, 8, 2, 0, 1, 4] 적합도= 475
# 염색체 # 6 = [7, 0, 1, 8, 6, 2, 3, 4, 5] 적합도= 436
# 염색체 # 7 = [7, 8, 2, 0, 5, 6, 3, 1, 4] 적합도= 362
# 염색체 # 8 = [7, 4, 2, 8, 6, 1, 3, 0, 5] 적합도= 361
# 염색체 # 9 = [7, 5, 0, 3, 2, 1, 8, 6, 4] 적합도= 310
# 염색체 # 10 = [7, 5, 8, 1, 6, 2, 3, 0, 4] 적합도= 310
# 염색체 # 11 = [7, 5, 8, 3, 2, 6, 0, 1, 4] 적합도= 281
# 염색체 # 12 = [8, 7, 1, 5, 6, 2, 3, 0, 4] 적합도= 236
# 염색체 # 13 = [7, 8, 5, 0, 2, 1, 3, 6, 4] 적합도= 212
# 염색체 # 14 = [8, 7, 0, 3, 2, 1, 6, 4, 5] 적합도= 173
# 염색체 # 15 = [7, 3, 8, 6, 1, 2, 0, 4, 5] 적합도= 114
#
# 세대 번호= 31
# 염색체 # 0 = [7, 5, 8, 0, 2, 1, 3, 4, 6] 적합도= 729
# 염색체 # 1 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 2 = [7, 5, 8, 6, 2, 3, 0, 1, 4] 적합도= 600
# 염색체 # 3 = [7, 8, 6, 4, 2, 3, 0, 1, 5] 적합도= 547
# 염색체 # 4 = [7, 8, 6, 0, 2, 1, 3, 4, 5] 적합도= 521
# 염색체 # 5 = [7, 5, 6, 3, 8, 2, 0, 1, 4] 적합도= 475
# 염색체 # 6 = [7, 5, 6, 3, 8, 2, 0, 1, 4] 적합도= 475
# 염색체 # 7 = [7, 5, 6, 3, 8, 2, 0, 1, 4] 적합도= 475
# 염색체 # 8 = [7, 5, 8, 1, 2, 6, 3, 0, 4] 적합도= 365
# 염색체 # 9 = [7, 1, 8, 5, 6, 2, 3, 0, 4] 적합도= 308
# 염색체 # 10 = [7, 8, 5, 0, 6, 2, 1, 3, 4] 적합도= 297
# 염색체 # 11 = [8, 7, 1, 5, 6, 2, 3, 0, 4] 적합도= 236
# 염색체 # 12 = [7, 8, 6, 0, 2, 1, 3, 5, 4] 적합도= 186
# 염색체 # 13 = [7, 5, 0, 3, 6, 2, 1, 8, 4] 적합도= 129
# 염색체 # 14 = [8, 7, 1, 5, 2, 6, 3, 0, 4] 적합도= 68
# 염색체 # 15 = [7, 1, 5, 0, 2, 8, 6, 3, 4] 적합도= 33
#
# 세대 번호= 32
# 염색체 # 0 = [7, 5, 6, 8, 2, 0, 3, 1, 4] 적합도= 709
# 염색체 # 1 = [7, 5, 6, 4, 2, 3, 0, 1, 8] 적합도= 688
# 염색체 # 2 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 3 = [7, 5, 6, 3, 8, 2, 0, 1, 4] 적합도= 475
# 염색체 # 4 = [7, 5, 6, 3, 8, 2, 0, 1, 4] 적합도= 475
# 염색체 # 5 = [7, 5, 6, 3, 8, 2, 0, 1, 4] 적합도= 475
# 염색체 # 6 = [7, 8, 6, 0, 2, 1, 4, 3, 5] 적합도= 403
# 염색체 # 7 = [8, 7, 6, 3, 1, 5, 2, 0, 4] 적합도= 378
# 염색체 # 8 = [7, 2, 8, 4, 6, 3, 0, 1, 5] 적합도= 375
# 염색체 # 9 = [7, 8, 6, 0, 1, 5, 2, 3, 4] 적합도= 351
# 염색체 # 10 = [7, 3, 8, 5, 6, 2, 0, 1, 4] 적합도= 311
# 염색체 # 11 = [7, 8, 5, 0, 6, 2, 1, 3, 4] 적합도= 297
# 염색체 # 12 = [8, 7, 1, 5, 6, 2, 3, 0, 4] 적합도= 236
# 염색체 # 13 = [7, 6, 1, 5, 3, 8, 2, 0, 4] 적합도= 143
# 염색체 # 14 = [8, 7, 1, 5, 2, 6, 3, 0, 4] 적합도= 68
# 염색체 # 15 = [7, 1, 5, 0, 8, 6, 2, 3, 4] 적합도= 1
#
# 세대 번호= 33
# 염색체 # 0 = [7, 8, 6, 5, 2, 0, 3, 1, 4] 적합도= 617
# 염색체 # 1 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 2 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 3 = [7, 8, 2, 4, 6, 3, 0, 1, 5] 적합도= 508
# 염색체 # 4 = [7, 2, 8, 4, 6, 3, 0, 1, 5] 적합도= 375
# 염색체 # 5 = [7, 8, 6, 0, 1, 5, 2, 3, 4] 적합도= 351
# 염색체 # 6 = [7, 5, 6, 4, 2, 3, 0, 8, 1] 적합도= 318
# 염색체 # 7 = [7, 8, 5, 0, 6, 2, 1, 3, 4] 적합도= 297
# 염색체 # 8 = [7, 5, 6, 3, 8, 2, 0, 4, 1] 적합도= 290
# 염색체 # 9 = [7, 6, 3, 5, 1, 0, 8, 2, 4] 적합도= 283
# 염색체 # 10 = [7, 6, 0, 3, 8, 2, 1, 5, 4] 적합도= 273
# 염색체 # 11 = [7, 8, 6, 3, 1, 5, 2, 0, 4] 적합도= 253
# 염색체 # 12 = [7, 5, 6, 3, 8, 0, 2, 1, 4] 적합도= 238
# 염색체 # 13 = [7, 8, 4, 6, 2, 5, 1, 3, 0] 적합도= 186
# 염색체 # 14 = [7, 8, 6, 0, 4, 2, 5, 3, 1] 적합도= 140
# 염색체 # 15 = [7, 8, 5, 0, 6, 3, 2, 1, 4] 적합도= 30
#
# 세대 번호= 34
# 염색체 # 0 = [7, 8, 6, 5, 2, 0, 1, 3, 4] 적합도= 758
# 염색체 # 1 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 2 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 3 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 4 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 5 = [7, 8, 2, 3, 4, 6, 0, 1, 5] 적합도= 503
# 염색체 # 6 = [7, 6, 5, 3, 8, 1, 2, 0, 4] 적합도= 378
# 염색체 # 7 = [7, 8, 6, 0, 1, 5, 2, 3, 4] 적합도= 351
# 염색체 # 8 = [7, 8, 6, 4, 3, 1, 5, 2, 0] 적합도= 327
# 염색체 # 9 = [7, 8, 6, 3, 5, 2, 0, 1, 4] 적합도= 307
# 염색체 # 10 = [7, 6, 0, 3, 8, 2, 1, 5, 4] 적합도= 273
# 염색체 # 11 = [7, 6, 0, 3, 8, 2, 1, 5, 4] 적합도= 273
# 염색체 # 12 = [7, 6, 0, 3, 8, 2, 1, 5, 4] 적합도= 273
# 염색체 # 13 = [7, 8, 6, 3, 1, 5, 2, 0, 4] 적합도= 253
# 염색체 # 14 = [7, 3, 4, 6, 2, 5, 8, 0, 1] 적합도= 250
# 염색체 # 15 = [7, 4, 5, 3, 8, 2, 6, 1, 0] 적합도= 1
#
# 세대 번호= 35
# 염색체 # 0 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 1 = [7, 8, 6, 5, 2, 0, 1, 3, 4] 적합도= 758
# 염색체 # 2 = [7, 8, 6, 5, 2, 3, 0, 1, 4] 적합도= 659
# 염색체 # 3 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 4 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 5 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 6 = [7, 8, 6, 5, 3, 2, 0, 1, 4] 적합도= 475
# 염색체 # 7 = [7, 6, 8, 3, 5, 2, 0, 1, 4] 적합도= 445
# 염색체 # 8 = [7, 8, 2, 1, 4, 6, 0, 3, 5] 적합도= 404
# 염색체 # 9 = [7, 8, 6, 3, 5, 2, 0, 1, 4] 적합도= 307
# 염색체 # 10 = [2, 6, 5, 3, 8, 7, 0, 1, 4] 적합도= 264
# 염색체 # 11 = [2, 6, 5, 3, 8, 7, 0, 1, 4] 적합도= 264
# 염색체 # 12 = [7, 4, 6, 3, 8, 2, 0, 1, 5] 적합도= 250
# 염색체 # 13 = [7, 3, 4, 6, 2, 5, 8, 0, 1] 적합도= 250
# 염색체 # 14 = [7, 5, 8, 3, 4, 6, 0, 2, 1] 적합도= 196
# 염색체 # 15 = [7, 8, 6, 3, 5, 2, 0, 4, 1] 적합도= 122
#
# 세대 번호= 36
# 염색체 # 0 = [7, 6, 5, 2, 8, 3, 0, 1, 4] 적합도= 758
# 염색체 # 1 = [7, 8, 6, 5, 2, 0, 1, 3, 4] 적합도= 758
# 염색체 # 2 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 3 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 4 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 5 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 6 = [7, 6, 8, 5, 3, 2, 0, 1, 4] 적합도= 531
# 염색체 # 7 = [7, 8, 6, 5, 3, 2, 0, 1, 4] 적합도= 475
# 염색체 # 8 = [7, 8, 6, 5, 3, 2, 0, 1, 4] 적합도= 475
# 염색체 # 9 = [3, 8, 6, 5, 2, 7, 0, 1, 4] 적합도= 456
# 염색체 # 10 = [7, 6, 8, 3, 5, 2, 0, 1, 4] 적합도= 445
# 염색체 # 11 = [7, 6, 8, 3, 5, 2, 0, 1, 4] 적합도= 445
# 염색체 # 12 = [7, 6, 8, 3, 5, 2, 0, 1, 4] 적합도= 445
# 염색체 # 13 = [7, 8, 6, 3, 5, 2, 0, 1, 4] 적합도= 307
# 염색체 # 14 = [7, 8, 6, 3, 5, 1, 0, 2, 4] 적합도= 172
# 염색체 # 15 = [7, 8, 6, 3, 5, 2, 0, 4, 1] 적합도= 122
#
# 세대 번호= 37
# 염색체 # 0 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 1 = [7, 8, 6, 5, 2, 0, 1, 3, 4] 적합도= 758
# 염색체 # 2 = [7, 6, 5, 2, 8, 3, 0, 1, 4] 적합도= 758
# 염색체 # 3 = [7, 6, 5, 3, 1, 2, 0, 4, 8] 적합도= 588
# 염색체 # 4 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 5 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 6 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 7 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 8 = [7, 6, 8, 5, 3, 2, 0, 1, 4] 적합도= 531
# 염색체 # 9 = [7, 6, 8, 5, 3, 2, 0, 1, 4] 적합도= 531
# 염색체 # 10 = [7, 8, 6, 5, 3, 2, 0, 1, 4] 적합도= 475
# 염색체 # 11 = [7, 8, 6, 5, 3, 2, 0, 1, 4] 적합도= 475
# 염색체 # 12 = [7, 6, 8, 3, 5, 2, 0, 1, 4] 적합도= 445
# 염색체 # 13 = [7, 8, 6, 3, 5, 2, 0, 1, 4] 적합도= 307
# 염색체 # 14 = [8, 6, 5, 3, 2, 7, 0, 1, 4] 적합도= 239
# 염색체 # 15 = [4, 6, 5, 3, 8, 2, 0, 1, 7] 적합도= 235
#
# 세대 번호= 38
# 염색체 # 0 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 8, 5, 2, 0, 1, 3, 4] 적합도= 814
# 염색체 # 3 = [7, 6, 5, 2, 8, 3, 0, 1, 4] 적합도= 758
# 염색체 # 4 = [7, 8, 6, 5, 2, 3, 0, 1, 4] 적합도= 659
# 염색체 # 5 = [7, 6, 5, 8, 3, 2, 0, 1, 4] 적합도= 607
# 염색체 # 6 = [7, 6, 5, 3, 1, 2, 0, 4, 8] 적합도= 588
# 염색체 # 7 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 8 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 9 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 10 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 11 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 12 = [7, 6, 3, 5, 8, 2, 0, 1, 4] 적합도= 492
# 염색체 # 13 = [7, 6, 8, 3, 5, 2, 0, 1, 4] 적합도= 445
# 염색체 # 14 = [7, 8, 6, 3, 5, 2, 0, 1, 4] 적합도= 307
# 염색체 # 15 = [7, 1, 3, 5, 2, 8, 0, 6, 4] 적합도= 1
#
# 세대 번호= 39
# 염색체 # 0 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 1 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 2 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 3 = [7, 6, 8, 5, 2, 0, 1, 3, 4] 적합도= 814
# 염색체 # 4 = [7, 6, 5, 2, 8, 3, 0, 1, 4] 적합도= 758
# 염색체 # 5 = [7, 6, 8, 5, 2, 0, 3, 1, 4] 적합도= 673
# 염색체 # 6 = [7, 8, 6, 5, 2, 3, 0, 1, 4] 적합도= 659
# 염색체 # 7 = [7, 6, 5, 8, 3, 2, 0, 1, 4] 적합도= 607
# 염색체 # 8 = [7, 6, 5, 8, 3, 2, 0, 1, 4] 적합도= 607
# 염색체 # 9 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 10 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 11 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 12 = [7, 6, 8, 5, 3, 1, 2, 0, 4] 적합도= 519
# 염색체 # 13 = [7, 6, 3, 5, 8, 2, 0, 1, 4] 적합도= 492
# 염색체 # 14 = [7, 6, 8, 3, 5, 2, 0, 1, 4] 적합도= 445
# 염색체 # 15 = [4, 6, 3, 8, 5, 2, 0, 1, 7] 적합도= 100
#
# 세대 번호= 40
# 염색체 # 0 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 1 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 2 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 5 = [7, 6, 5, 8, 2, 0, 3, 1, 4] 적합도= 802
# 염색체 # 6 = [7, 6, 8, 5, 2, 3, 0, 1, 4] 적합도= 715
# 염색체 # 7 = [7, 6, 4, 3, 8, 2, 0, 1, 5] 적합도= 684
# 염색체 # 8 = [7, 8, 6, 5, 2, 3, 0, 1, 4] 적합도= 659
# 염색체 # 9 = [7, 6, 5, 8, 3, 2, 0, 1, 4] 적합도= 607
# 염색체 # 10 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 11 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 12 = [7, 6, 8, 5, 3, 1, 2, 0, 4] 적합도= 519
# 염색체 # 13 = [7, 6, 3, 5, 8, 2, 0, 1, 4] 적합도= 492
# 염색체 # 14 = [7, 6, 3, 5, 2, 8, 0, 1, 4] 적합도= 418
# 염색체 # 15 = [2, 6, 3, 5, 8, 7, 0, 1, 4] 적합도= 182
#
# 세대 번호= 41
# 염색체 # 0 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 1 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 2 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 3 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 4 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 5 = [7, 6, 5, 8, 2, 0, 3, 1, 4] 적합도= 802
# 염색체 # 6 = [7, 6, 8, 5, 2, 3, 0, 1, 4] 적합도= 715
# 염색체 # 7 = [7, 8, 6, 5, 2, 3, 0, 1, 4] 적합도= 659
# 염색체 # 8 = [7, 8, 6, 5, 2, 0, 3, 1, 4] 적합도= 617
# 염색체 # 9 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 10 = [7, 6, 5, 3, 2, 8, 0, 1, 4] 적합도= 586
# 염색체 # 11 = [7, 4, 5, 8, 2, 3, 0, 1, 6] 적합도= 585
# 염색체 # 12 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 13 = [7, 6, 4, 3, 8, 5, 2, 0, 1] 적합도= 534
# 염색체 # 14 = [7, 6, 8, 5, 3, 2, 0, 1, 4] 적합도= 531
# 염색체 # 15 = [2, 6, 3, 5, 8, 7, 0, 1, 4] 적합도= 182
#
# 세대 번호= 42
# 염색체 # 0 = [7, 6, 5, 8, 2, 0, 1, 3, 4] 적합도= 943
# 염색체 # 1 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 2 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 5 = [7, 6, 5, 8, 2, 0, 1, 4, 3] 적합도= 814
# 염색체 # 6 = [7, 6, 5, 8, 2, 0, 3, 1, 4] 적합도= 802
# 염색체 # 7 = [7, 6, 5, 8, 2, 0, 3, 4, 1] 적합도= 758
# 염색체 # 8 = [7, 6, 4, 5, 8, 2, 0, 1, 3] 적합도= 620
# 염색체 # 9 = [7, 8, 6, 5, 2, 0, 3, 1, 4] 적합도= 617
# 염색체 # 10 = [7, 6, 5, 3, 8, 2, 0, 1, 4] 적합도= 574
# 염색체 # 11 = [8, 6, 7, 5, 3, 2, 0, 1, 4] 적합도= 563
# 염색체 # 12 = [7, 6, 8, 5, 1, 3, 0, 2, 4] 적합도= 538
# 염색체 # 13 = [7, 6, 4, 3, 8, 5, 2, 0, 1] 적합도= 534
# 염색체 # 14 = [7, 6, 4, 3, 8, 5, 2, 0, 1] 적합도= 534
# 염색체 # 15 = [7, 6, 5, 0, 3, 8, 2, 4, 1] 적합도= 418
#
# 세대 번호= 43
# 염색체 # 0 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 1 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 5 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 6 = [5, 6, 7, 8, 2, 0, 4, 3, 1] 적합도= 816
# 염색체 # 7 = [7, 6, 5, 8, 2, 0, 3, 1, 4] 적합도= 802
# 염색체 # 8 = [7, 6, 5, 8, 2, 4, 0, 1, 3] 적합도= 776
# 염색체 # 9 = [7, 6, 5, 8, 2, 0, 3, 4, 1] 적합도= 758
# 염색체 # 10 = [7, 6, 5, 8, 3, 2, 0, 1, 4] 적합도= 607
# 염색체 # 11 = [3, 6, 5, 8, 2, 7, 0, 1, 4] 적합도= 503
# 염색체 # 12 = [7, 6, 5, 0, 3, 8, 2, 4, 1] 적합도= 418
# 염색체 # 13 = [7, 5, 4, 3, 8, 6, 2, 0, 1] 적합도= 404
# 염색체 # 14 = [7, 4, 5, 3, 8, 2, 0, 1, 6] 적합도= 315
# 염색체 # 15 = [7, 1, 5, 8, 2, 0, 3, 6, 4] 적합도= 99
#
# 세대 번호= 44
# 염색체 # 0 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 5 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 6 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 7 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 8 = [7, 6, 5, 8, 2, 0, 3, 1, 4] 적합도= 802
# 염색체 # 9 = [7, 6, 5, 8, 2, 0, 4, 1, 3] 적합도= 673
# 염색체 # 10 = [7, 6, 5, 8, 2, 3, 0, 4, 1] 적합도= 659
# 염색체 # 11 = [5, 6, 7, 8, 0, 2, 4, 3, 1] 적합도= 652
# 염색체 # 12 = [7, 5, 4, 3, 8, 6, 2, 0, 1] 적합도= 404
# 염색체 # 13 = [7, 6, 0, 8, 2, 5, 3, 4, 1] 적합도= 289
# 염색체 # 14 = [7, 4, 5, 8, 2, 6, 0, 3, 1] 적합도= 215
# 염색체 # 15 = [7, 4, 5, 3, 8, 0, 2, 1, 6] 적합도= 78
#
# 세대 번호= 45
# 염색체 # 0 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 5 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 6 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 7 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 8 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 9 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 10 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 11 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 12 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 13 = [7, 6, 5, 8, 2, 0, 3, 1, 4] 적합도= 802
# 염색체 # 14 = [7, 6, 5, 8, 2, 3, 0, 4, 1] 적합도= 659
# 염색체 # 15 = [0, 6, 5, 8, 2, 3, 7, 1, 4] 적합도= 152
#
# 세대 번호= 46
# 염색체 # 0 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 5 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 6 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 7 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 8 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 9 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 10 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 11 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 12 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 13 = [7, 6, 5, 8, 2, 0, 3, 1, 4] 적합도= 802
# 염색체 # 14 = [2, 6, 5, 8, 7, 3, 0, 1, 4] 적합도= 569
# 염색체 # 15 = [7, 6, 5, 8, 0, 3, 2, 4, 1] 적합도= 495
#
# 세대 번호= 47
# 염색체 # 0 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 1 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 5 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 6 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 7 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 8 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 9 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 10 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 11 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 12 = [6, 5, 7, 8, 2, 3, 0, 1, 4] 적합도= 811
# 염색체 # 13 = [7, 8, 5, 6, 2, 3, 0, 1, 4] 적합도= 637
# 염색체 # 14 = [6, 5, 2, 8, 7, 3, 0, 1, 4] 적합도= 630
# 염색체 # 15 = [2, 6, 5, 8, 7, 3, 0, 1, 4] 적합도= 569
#
# 세대 번호= 48
# 염색체 # 0 = [7, 6, 5, 8, 2, 4, 3, 0, 1] 적합도= 861
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 4 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 5 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 6 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 7 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 8 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 9 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 10 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 11 = [7, 6, 5, 8, 2, 3, 4, 0, 1] 적합도= 800
# 염색체 # 12 = [7, 6, 5, 8, 2, 1, 3, 4, 0] 적합도= 767
# 염색체 # 13 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 14 = [7, 6, 3, 8, 2, 5, 0, 1, 4] 적합도= 374
# 염색체 # 15 = [0, 6, 5, 8, 2, 3, 7, 1, 4] 적합도= 152
#
# 세대 번호= 49
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 3 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 4 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 5 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 6 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 7 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 8 = [7, 6, 5, 8, 2, 3, 4, 0, 1] 적합도= 800
# 염색체 # 9 = [7, 6, 5, 8, 2, 3, 4, 0, 1] 적합도= 800
# 염색체 # 10 = [7, 6, 5, 8, 2, 1, 3, 4, 0] 적합도= 767
# 염색체 # 11 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 12 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 13 = [7, 6, 5, 8, 4, 1, 3, 0, 2] 적합도= 690
# 염색체 # 14 = [7, 6, 5, 8, 0, 1, 3, 2, 4] 적합도= 680
# 염색체 # 15 = [8, 6, 5, 7, 2, 3, 0, 1, 4] 적합도= 639
#
# 세대 번호= 50
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 4 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 5 = [7, 6, 5, 8, 2, 1, 3, 4, 0] 적합도= 767
# 염색체 # 6 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 7 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 8 = [7, 6, 5, 8, 3, 0, 1, 2, 4] 적합도= 698
# 염색체 # 9 = [7, 6, 5, 8, 0, 3, 2, 1, 4] 적합도= 607
# 염색체 # 10 = [7, 6, 5, 8, 0, 3, 2, 1, 4] 적합도= 607
# 염색체 # 11 = [7, 6, 5, 2, 8, 3, 1, 4, 0] 적합도= 552
# 염색체 # 12 = [7, 6, 5, 2, 8, 3, 1, 4, 0] 적합도= 552
# 염색체 # 13 = [7, 6, 5, 3, 4, 1, 8, 2, 0] 적합도= 520
# 염색체 # 14 = [7, 6, 1, 8, 2, 5, 3, 0, 4] 적합도= 392
# 염색체 # 15 = [7, 6, 0, 8, 2, 1, 3, 5, 4] 적합도= 297
#
# 세대 번호= 51
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 3 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 4 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 5 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 6 = [7, 6, 5, 2, 8, 3, 1, 0, 4] 적합도= 758
# 염색체 # 7 = [7, 6, 5, 8, 3, 0, 1, 2, 4] 적합도= 698
# 염색체 # 8 = [7, 6, 5, 8, 3, 0, 1, 2, 4] 적합도= 698
# 염색체 # 9 = [7, 6, 5, 8, 0, 3, 2, 1, 4] 적합도= 607
# 염색체 # 10 = [7, 6, 5, 8, 0, 3, 2, 1, 4] 적합도= 607
# 염색체 # 11 = [7, 6, 5, 2, 8, 3, 1, 4, 0] 적합도= 552
# 염색체 # 12 = [7, 6, 5, 2, 8, 3, 1, 4, 0] 적합도= 552
# 염색체 # 13 = [7, 6, 5, 3, 4, 1, 8, 2, 0] 적합도= 520
# 염색체 # 14 = [7, 6, 5, 1, 2, 3, 0, 8, 4] 적합도= 391
# 염색체 # 15 = [0, 6, 5, 8, 2, 3, 4, 1, 7] 적합도= 216
#
# 세대 번호= 52
# 염색체 # 0 = [5, 6, 7, 8, 2, 3, 0, 1, 4] 적합도= 889
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 3 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 4 = [7, 6, 5, 8, 3, 0, 1, 2, 4] 적합도= 698
# 염색체 # 5 = [7, 6, 5, 8, 3, 0, 1, 2, 4] 적합도= 698
# 염색체 # 6 = [7, 6, 5, 8, 1, 2, 3, 0, 4] 적합도= 648
# 염색체 # 7 = [7, 6, 5, 8, 2, 3, 1, 4, 0] 적합도= 638
# 염색체 # 8 = [7, 6, 5, 8, 0, 3, 2, 1, 4] 적합도= 607
# 염색체 # 9 = [7, 6, 5, 8, 0, 3, 2, 1, 4] 적합도= 607
# 염색체 # 10 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 11 = [7, 6, 5, 3, 4, 1, 8, 2, 0] 적합도= 520
# 염색체 # 12 = [7, 6, 5, 8, 3, 1, 2, 4, 0] 적합도= 492
# 염색체 # 13 = [7, 6, 5, 1, 2, 3, 0, 8, 4] 적합도= 391
# 염색체 # 14 = [0, 6, 5, 8, 2, 3, 4, 1, 7] 적합도= 216
# 염색체 # 15 = [7, 8, 5, 3, 4, 1, 6, 2, 0] 적합도= 153
#
# 세대 번호= 53
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 2 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 3 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 4 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 5 = [5, 6, 7, 8, 3, 0, 1, 2, 4] 적합도= 743
# 염색체 # 6 = [6, 5, 7, 8, 3, 0, 1, 2, 4] 적합도= 665
# 염색체 # 7 = [7, 6, 5, 8, 1, 2, 3, 0, 4] 적합도= 648
# 염색체 # 8 = [7, 6, 5, 8, 0, 3, 2, 1, 4] 적합도= 607
# 염색체 # 9 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 10 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 11 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 12 = [7, 6, 5, 8, 0, 3, 2, 4, 1] 적합도= 495
# 염색체 # 13 = [7, 6, 5, 3, 1, 8, 2, 4, 0] 적합도= 482
# 염색체 # 14 = [7, 6, 4, 8, 2, 5, 3, 1, 0] 적합도= 447
# 염색체 # 15 = [7, 2, 5, 1, 6, 3, 0, 8, 4] 적합도= 1
#
# 세대 번호= 54
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 0, 1, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 2 = [5, 6, 7, 8, 3, 0, 1, 2, 4] 적합도= 743
# 염색체 # 3 = [6, 5, 7, 8, 3, 0, 1, 2, 4] 적합도= 665
# 염색체 # 4 = [6, 5, 7, 8, 3, 0, 1, 2, 4] 적합도= 665
# 염색체 # 5 = [6, 5, 7, 8, 3, 0, 1, 2, 4] 적합도= 665
# 염색체 # 6 = [7, 6, 5, 1, 0, 3, 8, 2, 4] 적합도= 623
# 염색체 # 7 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 8 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 9 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 10 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 11 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 12 = [7, 6, 5, 2, 1, 8, 3, 0, 4] 적합도= 562
# 염색체 # 13 = [7, 6, 4, 8, 2, 5, 3, 1, 0] 적합도= 447
# 염색체 # 14 = [7, 6, 5, 0, 1, 8, 3, 2, 4] 적합도= 419
# 염색체 # 15 = [7, 3, 5, 1, 2, 6, 8, 0, 4] 적합도= 1
#
# 세대 번호= 55
# 염색체 # 0 = [7, 6, 5, 8, 2, 4, 3, 1, 0] 적합도= 840
# 염색체 # 1 = [7, 6, 5, 1, 0, 3, 8, 2, 4] 적합도= 623
# 염색체 # 2 = [6, 5, 7, 8, 3, 2, 1, 0, 4] 적합도= 604
# 염색체 # 3 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 4 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 5 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 6 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 7 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 8 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 9 = [7, 6, 8, 2, 4, 5, 3, 1, 0] 적합도= 513
# 염색체 # 10 = [7, 6, 5, 2, 1, 8, 3, 4, 0] 적합도= 497
# 염색체 # 11 = [7, 6, 5, 0, 1, 8, 3, 2, 4] 적합도= 419
# 염색체 # 12 = [7, 6, 5, 3, 4, 2, 1, 8, 0] 적합도= 386
# 염색체 # 13 = [7, 6, 5, 3, 2, 4, 8, 0, 1] 적합도= 333
# 염색체 # 14 = [7, 2, 5, 3, 8, 6, 0, 1, 4] 적합도= 126
# 염색체 # 15 = [7, 1, 5, 6, 3, 8, 2, 0, 4] 적합도= 42
#
# 세대 번호= 56
# 염색체 # 0 = [7, 6, 5, 8, 2, 1, 4, 3, 0] 적합도= 767
# 염색체 # 1 = [7, 6, 5, 8, 3, 4, 2, 0, 1] 적합도= 624
# 염색체 # 2 = [7, 6, 5, 3, 4, 2, 8, 1, 0] 적합도= 623
# 염색체 # 3 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 4 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 5 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 6 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 7 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 8 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 9 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 10 = [7, 6, 5, 2, 1, 8, 3, 0, 4] 적합도= 562
# 염색체 # 11 = [7, 6, 8, 2, 4, 5, 3, 1, 0] 적합도= 513
# 염색체 # 12 = [7, 6, 5, 8, 3, 1, 2, 4, 0] 적합도= 492
# 염색체 # 13 = [7, 6, 5, 3, 8, 1, 2, 0, 4] 적합도= 378
# 염색체 # 14 = [7, 0, 5, 3, 2, 4, 1, 8, 6] 적합도= 137
# 염색체 # 15 = [7, 2, 5, 8, 3, 4, 1, 6, 0] 적합도= 1
#
# 세대 번호= 57
# 염색체 # 0 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 1 = [7, 6, 5, 8, 2, 1, 4, 3, 0] 적합도= 767
# 염색체 # 2 = [7, 6, 5, 3, 4, 2, 8, 0, 1] 적합도= 603
# 염색체 # 3 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 4 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 5 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 6 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 7 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 8 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 9 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 10 = [7, 6, 5, 2, 1, 8, 4, 3, 0] 적합도= 563
# 염색체 # 11 = [7, 6, 5, 2, 1, 8, 3, 0, 4] 적합도= 562
# 염색체 # 12 = [7, 6, 5, 2, 1, 8, 3, 0, 4] 적합도= 562
# 염색체 # 13 = [7, 6, 5, 2, 1, 8, 3, 0, 4] 적합도= 562
# 염색체 # 14 = [7, 6, 8, 2, 0, 5, 3, 1, 4] 적합도= 424
# 염색체 # 15 = [7, 0, 5, 8, 3, 1, 2, 6, 4] 적합도= 19
# 세대 번호= 58
# 염색체 # 0 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 1 = [7, 6, 5, 8, 2, 1, 4, 3, 0] 적합도= 767
# 염색체 # 2 = [7, 6, 5, 3, 4, 2, 8, 1, 0] 적합도= 623
# 염색체 # 3 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 4 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 5 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 6 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 7 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 8 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 9 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 10 = [7, 6, 2, 0, 1, 8, 5, 3, 4] 적합도= 575
# 염색체 # 11 = [7, 6, 3, 1, 0, 5, 8, 2, 4] 적합도= 521
# 염색체 # 12 = [7, 6, 5, 2, 1, 8, 3, 4, 0] 적합도= 497
# 염색체 # 13 = [7, 6, 5, 3, 1, 8, 2, 4, 0] 적합도= 482
# 염색체 # 14 = [7, 6, 8, 2, 0, 5, 3, 1, 4] 적합도= 424
# 염색체 # 15 = [7, 2, 5, 8, 6, 1, 3, 0, 4] 적합도= 372
#
# 세대 번호= 59
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 2, 1, 3, 0, 4] 적합도= 832
# 염색체 # 2 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 3 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 4 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 5 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 6 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 7 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 8 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 9 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 10 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 11 = [7, 6, 2, 0, 1, 8, 5, 3, 4] 적합도= 575
# 염색체 # 12 = [7, 6, 5, 3, 1, 8, 2, 4, 0] 적합도= 482
# 염색체 # 13 = [7, 6, 8, 2, 0, 5, 3, 1, 4] 적합도= 424
# 염색체 # 14 = [7, 6, 1, 2, 0, 8, 5, 3, 4] 적합도= 329
# 염색체 # 15 = [7, 6, 1, 5, 3, 8, 2, 0, 4] 적합도= 143
#
# 세대 번호= 60
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 2 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 3 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 4 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 5 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 6 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 7 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 8 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 9 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 10 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 11 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 12 = [7, 6, 2, 0, 1, 8, 5, 3, 4] 적합도= 575
# 염색체 # 13 = [7, 6, 5, 3, 1, 8, 2, 4, 0] 적합도= 482
# 염색체 # 14 = [7, 6, 8, 2, 0, 5, 3, 1, 4] 적합도= 424
# 염색체 # 15 = [7, 1, 5, 8, 3, 6, 2, 0, 4] 적합도= 1
#
# 세대 번호= 61
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 1 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 2 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 3 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 4 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 5 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 6 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 7 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 8 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 9 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 10 = [7, 6, 5, 3, 1, 8, 2, 0, 4] 적합도= 585
# 염색체 # 11 = [7, 6, 5, 3, 1, 8, 2, 4, 0] 적합도= 482
# 염색체 # 12 = [7, 6, 1, 3, 5, 8, 2, 0, 4] 적합도= 425
# 염색체 # 13 = [7, 6, 8, 2, 0, 5, 3, 1, 4] 적합도= 424
# 염색체 # 14 = [7, 6, 8, 2, 0, 5, 3, 1, 4] 적합도= 424
# 염색체 # 15 = [7, 2, 5, 3, 1, 8, 6, 0, 4] 적합도= 137
#
# 세대 번호= 62
# 염색체 # 0 = [7, 6, 5, 8, 2, 3, 1, 0, 4] 적합도= 844
# 염색체 # 1 = [6, 7, 5, 3, 1, 8, 2, 0, 4] 적합도= 608
# 염색체 # 2 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 3 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 4 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 5 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 6 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# 염색체 # 7 = [7, 6, 5, 8, 3, 1, 2, 0, 4] 적합도= 595
# ...
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 6 = [5, 6, 7, 8, 4, 1, 3, 0, 2] 적합도= 742
# 염색체 # 7 = [5, 6, 7, 4, 3, 8, 0, 1, 2] 적합도= 662
# 염색체 # 8 = [5, 6, 7, 8, 0, 2, 1, 4, 3] 적합도= 633
# 염색체 # 9 = [5, 6, 7, 8, 0, 2, 1, 4, 3] 적합도= 633
# 염색체 # 10 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 11 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 12 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 13 = [5, 6, 7, 4, 0, 8, 1, 3, 2] 적합도= 544
# 염색체 # 14 = [5, 6, 3, 4, 7, 0, 1, 8, 2] 적합도= 411
# 염색체 # 15 = [5, 3, 7, 8, 0, 1, 4, 6, 2] 적합도= 221
#
# 세대 번호= 122
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 8 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 9 = [5, 6, 7, 8, 4, 1, 0, 2, 3] 적합도= 600
# 염색체 # 10 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 11 = [5, 6, 7, 8, 0, 2, 4, 1, 3] 적합도= 565
# 염색체 # 12 = [5, 6, 7, 4, 0, 8, 1, 3, 2] 적합도= 544
# 염색체 # 13 = [5, 6, 3, 4, 7, 0, 1, 8, 2] 적합도= 411
# 염색체 # 14 = [3, 6, 7, 8, 0, 2, 1, 4, 5] 적합도= 300
# 염색체 # 15 = [5, 3, 7, 4, 0, 1, 8, 6, 2] 적합도= 202
#
# 세대 번호= 123
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 9 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 10 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 11 = [5, 6, 7, 8, 4, 1, 0, 2, 3] 적합도= 600
# 염색체 # 12 = [5, 6, 3, 4, 0, 1, 8, 7, 2] 적합도= 594
# 염색체 # 13 = [5, 6, 7, 4, 0, 8, 1, 3, 2] 적합도= 544
# 염색체 # 14 = [5, 6, 7, 4, 0, 8, 1, 3, 2] 적합도= 544
# 염색체 # 15 = [3, 1, 7, 8, 0, 2, 6, 5, 4] 적합도= 411
#
# 세대 번호= 124
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 9 = [5, 6, 3, 4, 0, 1, 8, 7, 2] 적합도= 594
# 염색체 # 10 = [5, 6, 7, 4, 0, 8, 1, 3, 2] 적합도= 544
# 염색체 # 11 = [5, 6, 7, 4, 0, 8, 1, 3, 2] 적합도= 544
# 염색체 # 12 = [5, 6, 7, 4, 0, 8, 1, 3, 2] 적합도= 544
# 염색체 # 13 = [5, 6, 7, 1, 4, 0, 8, 3, 2] 적합도= 348
# 염색체 # 14 = [5, 4, 7, 6, 0, 8, 1, 3, 2] 적합도= 267
# 염색체 # 15 = [5, 6, 1, 8, 4, 0, 7, 3, 2] 적합도= 1
#
# 세대 번호= 125
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 9 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 10 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 11 = [5, 6, 3, 4, 0, 1, 8, 7, 2] 적합도= 594
# 염색체 # 12 = [4, 6, 7, 8, 0, 1, 5, 3, 2] 적합도= 382
# 염색체 # 13 = [5, 6, 7, 1, 4, 0, 8, 3, 2] 적합도= 348
# 염색체 # 14 = [5, 4, 7, 6, 0, 8, 1, 3, 2] 적합도= 267
# 염색체 # 15 = [5, 7, 4, 6, 0, 8, 1, 3, 2] 적합도= 189
#
# 세대 번호= 126
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 9 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 10 = [5, 6, 2, 8, 0, 1, 4, 3, 7] 적합도= 625
# 염색체 # 11 = [5, 6, 3, 4, 0, 1, 8, 7, 2] 적합도= 594
# 염색체 # 12 = [5, 6, 3, 4, 0, 1, 8, 7, 2] 적합도= 594
# 염색체 # 13 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 14 = [5, 7, 4, 6, 0, 8, 1, 3, 2] 적합도= 189
# 염색체 # 15 = [5, 1, 7, 8, 0, 6, 3, 4, 2] 적합도= 1
#
# 세대 번호= 127
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 7, 6, 8, 3, 4, 0, 1, 2] 적합도= 810
# 염색체 # 9 = [5, 6, 2, 8, 0, 1, 4, 3, 7] 적합도= 625
# 염색체 # 10 = [5, 6, 3, 4, 0, 1, 8, 7, 2] 적합도= 594
# 염색체 # 11 = [5, 6, 3, 4, 0, 1, 8, 7, 2] 적합도= 594
# 염색체 # 12 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 13 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 14 = [5, 6, 3, 4, 7, 8, 0, 1, 2] 적합도= 524
# 염색체 # 15 = [5, 4, 7, 8, 0, 1, 6, 3, 2] 적합도= 136
#
# 세대 번호= 128
# 염색체 # 0 = [5, 6, 7, 8, 3, 4, 0, 1, 2] 적합도= 847
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 7, 6, 8, 3, 4, 0, 1, 2] 적합도= 810
# 염색체 # 9 = [5, 7, 6, 8, 2, 4, 0, 1, 3] 적합도= 795
# 염색체 # 10 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 11 = [5, 6, 7, 4, 0, 1, 3, 8, 2] 적합도= 758
# 염색체 # 12 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
# 염색체 # 13 = [5, 6, 3, 4, 7, 8, 0, 1, 2] 적합도= 524
# 염색체 # 14 = [5, 6, 3, 4, 7, 0, 1, 8, 2] 적합도= 411
# 염색체 # 15 = [5, 6, 3, 4, 0, 7, 8, 1, 2] 적합도= 359
#
# 세대 번호= 129
# 염색체 # 0 = [5, 6, 7, 8, 3, 4, 0, 1, 2] 적합도= 847
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 9 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 10 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 11 = [5, 7, 6, 8, 0, 4, 3, 1, 2] 적합도= 780
# 염색체 # 12 = [5, 7, 6, 8, 2, 4, 0, 3, 1] 적합도= 741
# 염색체 # 13 = [5, 7, 6, 8, 2, 1, 4, 0, 3] 적합도= 722
# 염색체 # 14 = [5, 6, 7, 8, 0, 4, 1, 3, 2] 적합도= 688
# 염색체 # 15 = [5, 6, 7, 4, 0, 1, 8, 3, 2] 적합도= 574
#
# 세대 번호= 130
# 염색체 # 0 = [5, 6, 7, 8, 3, 4, 0, 1, 2] 적합도= 847
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 8 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 9 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 10 = [5, 7, 6, 8, 2, 0, 4, 3, 1] 적합도= 779
# 염색체 # 11 = [5, 7, 6, 8, 2, 1, 4, 0, 3] 적합도= 722
# 염색체 # 12 = [5, 7, 6, 8, 0, 2, 1, 4, 3] 적합도= 596
# 염색체 # 13 = [5, 6, 7, 8, 0, 4, 2, 3, 1] 적합도= 553
# 염색체 # 14 = [4, 6, 7, 8, 0, 1, 5, 3, 2] 적합도= 382
# 염색체 # 15 = [1, 7, 6, 8, 0, 5, 4, 3, 2] 적합도= 303
#
# 세대 번호= 131
# 염색체 # 0 = [5, 6, 7, 8, 3, 4, 0, 1, 2] 적합도= 847
# 염색체 # 1 = [5, 6, 7, 8, 3, 4, 0, 1, 2] 적합도= 847
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 5 = [5, 6, 7, 8, 0, 3, 4, 1, 2] 적합도= 817
# 염색체 # 6 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 7 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 8 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 9 = [5, 7, 6, 8, 2, 0, 4, 3, 1] 적합도= 779
# 염색체 # 10 = [4, 6, 7, 5, 8, 0, 1, 3, 2] 적합도= 703
# 염색체 # 11 = [5, 7, 6, 8, 2, 0, 4, 1, 3] 적합도= 692
# 염색체 # 12 = [5, 7, 6, 8, 1, 2, 0, 4, 3] 적합도= 637
# 염색체 # 13 = [5, 7, 6, 4, 8, 0, 1, 3, 2] 적합도= 622
# 염색체 # 14 = [5, 7, 6, 8, 0, 1, 4, 2, 3] 적합도= 570
# 염색체 # 15 = [5, 6, 7, 8, 0, 4, 2, 3, 1] 적합도= 553
#
# 세대 번호= 132
# 염색체 # 0 = [5, 6, 7, 8, 3, 4, 0, 1, 2] 적합도= 847
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 3, 4, 1, 2] 적합도= 817
# 염색체 # 4 = [5, 6, 7, 8, 0, 3, 4, 1, 2] 적합도= 817
# 염색체 # 5 = [5, 7, 6, 8, 0, 1, 4, 3, 2] 적합도= 792
# 염색체 # 6 = [5, 6, 7, 8, 4, 1, 0, 3, 2] 적합도= 784
# 염색체 # 7 = [5, 7, 6, 8, 2, 0, 4, 3, 1] 적합도= 779
# 염색체 # 8 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 9 = [2, 6, 7, 8, 3, 0, 1, 4, 5] 적합도= 652
# 염색체 # 10 = [5, 7, 6, 8, 0, 2, 4, 3, 1] 적합도= 615
# 염색체 # 11 = [5, 7, 6, 8, 1, 2, 3, 4, 0] 적합도= 605
# 염색체 # 12 = [5, 6, 7, 8, 3, 4, 1, 2, 0] 적합도= 589
# 염색체 # 13 = [5, 6, 7, 8, 0, 2, 4, 1, 3] 적합도= 565
# 염색체 # 14 = [5, 6, 7, 8, 0, 4, 2, 3, 1] 적합도= 553
# 염색체 # 15 = [5, 1, 6, 8, 2, 0, 4, 3, 7] 적합도= 290
#
# 세대 번호= 133
# 염색체 # 0 = [7, 6, 8, 2, 3, 0, 1, 4, 5] 적합도= 852
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 3 = [5, 6, 7, 8, 0, 3, 4, 1, 2] 적합도= 817
# 염색체 # 4 = [5, 6, 7, 8, 4, 1, 0, 3, 2] 적합도= 784
# 염색체 # 5 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 6 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 7 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 8 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 9 = [5, 6, 7, 8, 0, 3, 1, 4, 2] 적합도= 749
# 염색체 # 10 = [6, 7, 8, 5, 2, 0, 4, 3, 1] 적합도= 668
# 염색체 # 11 = [5, 6, 7, 8, 0, 1, 4, 2, 3] 적합도= 607
# 염색체 # 12 = [5, 6, 7, 8, 4, 1, 0, 2, 3] 적합도= 600
# 염색체 # 13 = [5, 6, 7, 8, 0, 2, 4, 1, 3] 적합도= 565
# 염색체 # 14 = [5, 6, 7, 8, 0, 2, 4, 1, 3] 적합도= 565
# 염색체 # 15 = [5, 7, 1, 8, 0, 6, 4, 3, 2] 적합도= 145
#
# 세대 번호= 134
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 2, 3, 0, 1, 4] 적합도= 889
# 염색체 # 3 = [5, 6, 7, 8, 4, 3, 1, 0, 2] 적합도= 883
# 염색체 # 4 = [7, 6, 8, 2, 0, 1, 4, 3, 5] 적합도= 833
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 8 = [5, 6, 7, 8, 3, 0, 1, 4, 2] 적합도= 779
# 염색체 # 9 = [6, 7, 5, 8, 0, 1, 4, 3, 2] 적합도= 770
# 염색체 # 10 = [5, 6, 8, 2, 3, 0, 1, 4, 7] 적합도= 751
# 염색체 # 11 = [7, 2, 8, 5, 3, 0, 1, 4, 6] 적합도= 690
# 염색체 # 12 = [6, 7, 8, 5, 2, 0, 4, 3, 1] 적합도= 668
# 염색체 # 13 = [5, 6, 8, 7, 3, 0, 1, 4, 2] 적합도= 591
# 염색체 # 14 = [6, 8, 7, 5, 2, 0, 4, 3, 1] 적합도= 575
# 염색체 # 15 = [3, 6, 7, 8, 0, 1, 4, 2, 5] 적합도= 439
#
# 세대 번호= 135
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 5 = [5, 6, 7, 8, 4, 3, 1, 0, 2] 적합도= 883
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 6, 7, 8, 4, 0, 1, 3, 2] 적합도= 784
# 염색체 # 9 = [6, 7, 5, 8, 0, 1, 4, 3, 2] 적합도= 770
# 염색체 # 10 = [5, 6, 7, 8, 0, 3, 1, 4, 2] 적합도= 749
# 염색체 # 11 = [7, 2, 8, 5, 3, 0, 1, 4, 6] 적합도= 690
# 염색체 # 12 = [5, 6, 8, 7, 3, 0, 1, 4, 2] 적합도= 591
# 염색체 # 13 = [5, 6, 8, 7, 3, 0, 1, 4, 2] 적합도= 591
# 염색체 # 14 = [6, 8, 7, 5, 2, 0, 4, 3, 1] 적합도= 575
# 염색체 # 15 = [3, 6, 7, 8, 0, 1, 4, 2, 5] 적합도= 439
#
# 세대 번호= 136
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 9 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 10 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 11 = [6, 7, 5, 8, 0, 1, 4, 3, 2] 적합도= 770
# 염색체 # 12 = [2, 6, 7, 8, 5, 3, 0, 1, 4] 적합도= 681
# 염색체 # 13 = [5, 6, 8, 7, 3, 0, 1, 4, 2] 적합도= 591
# 염색체 # 14 = [5, 6, 8, 7, 3, 0, 1, 4, 2] 적합도= 591
# 염색체 # 15 = [6, 2, 1, 5, 7, 0, 8, 4, 3] 적합도= 43
#
# 세대 번호= 137
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 9 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 10 = [6, 7, 5, 8, 0, 1, 3, 4, 2] 적합도= 831
# 염색체 # 11 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 12 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 13 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 14 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 15 = [2, 6, 7, 8, 5, 3, 0, 1, 4] 적합도= 681
#
# 세대 번호= 138
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 4 = [6, 7, 5, 8, 0, 1, 3, 4, 2] 적합도= 831
# 염색체 # 5 = [6, 7, 5, 8, 0, 1, 3, 4, 2] 적합도= 831
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 9 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 10 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 11 = [5, 6, 7, 8, 2, 1, 3, 4, 0] 적합도= 826
# 염색체 # 12 = [5, 6, 7, 8, 0, 4, 3, 1, 2] 적합도= 817
# 염색체 # 13 = [5, 6, 7, 8, 4, 1, 3, 0, 2] 적합도= 742
# 염색체 # 14 = [5, 6, 7, 3, 0, 1, 4, 8, 2] 적합도= 695
# 염색체 # 15 = [6, 7, 2, 8, 5, 3, 0, 1, 4] 적합도= 690
#
# 세대 번호= 139
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 4 = [7, 6, 5, 8, 0, 1, 3, 4, 2] 적합도= 838
# 염색체 # 5 = [6, 7, 5, 8, 0, 1, 3, 4, 2] 적합도= 831
# 염색체 # 6 = [6, 7, 5, 8, 0, 1, 3, 4, 2] 적합도= 831
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 9 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 10 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 11 = [6, 5, 7, 8, 0, 1, 3, 4, 2] 적합도= 775
# 염색체 # 12 = [5, 6, 7, 8, 4, 1, 3, 0, 2] 적합도= 742
# 염색체 # 13 = [6, 5, 7, 8, 2, 1, 3, 4, 0] 적합도= 716
# 염색체 # 14 = [5, 6, 7, 3, 0, 1, 4, 8, 2] 적합도= 695
# 염색체 # 15 = [5, 6, 0, 8, 7, 1, 3, 4, 2] 적합도= 327
#
# 세대 번호= 140
# 염색체 # 0 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 4 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 7 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 8 = [6, 7, 5, 8, 0, 1, 3, 4, 2] 적합도= 831
# 염색체 # 9 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 10 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 11 = [5, 6, 7, 8, 4, 1, 3, 0, 2] 적합도= 742
# 염색체 # 12 = [5, 6, 7, 8, 0, 1, 2, 4, 3] 적합도= 736
# 염색체 # 13 = [6, 5, 7, 8, 2, 1, 3, 4, 0] 적합도= 716
# 염색체 # 14 = [6, 7, 5, 8, 4, 1, 3, 0, 2] 적합도= 683
# 염색체 # 15 = [1, 6, 7, 8, 0, 5, 3, 4, 2] 적합도= 285
#
# 세대 번호= 141
# 염색체 # 0 = [5, 6, 7, 8, 2, 1, 0, 3, 4] 적합도= 1018
# 염색체 # 1 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 2 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 3 = [5, 6, 7, 8, 0, 1, 3, 4, 2] 적합도= 890
# 염색체 # 4 = [6, 7, 5, 8, 0, 1, 3, 4, 2] 적합도= 831
# 염색체 # 5 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 6 = [5, 6, 7, 8, 0, 1, 4, 3, 2] 적합도= 829
# 염색체 # 7 = [5, 6, 7, 8, 4, 1, 3, 0, 2] 적합도= 742
# 염색체 # 8 = [5, 6, 7, 8, 0, 1, 2, 4, 3] 적합도= 736
# 염색체 # 9 = [5, 6, 7, 8, 0, 1, 2, 4, 3] 적합도= 736
# 염색체 # 10 = [5, 6, 7, 8, 0, 1, 3, 2, 4] 적합도= 725
# 염색체 # 11 = [6, 7, 5, 8, 4, 1, 0, 3, 2] 적합도= 725
# 염색체 # 12 = [6, 5, 7, 8, 0, 1, 2, 3, 4] 적합도= 715
# 염색체 # 13 = [5, 6, 7, 4, 0, 1, 2, 3, 8] 적합도= 637
# 염색체 # 14 = [1, 6, 7, 8, 0, 5, 4, 3, 2] 적합도= 342
# 염색체 # 15 = [5, 6, 4, 8, 0, 1, 3, 7, 2] 적합도= 333
